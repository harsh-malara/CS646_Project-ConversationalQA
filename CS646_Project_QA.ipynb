# %%
import torch

# Confirm that the GPU is detected

assert torch.cuda.is_available()

# Get the GPU device name.
device_name = torch.cuda.get_device_name()
n_gpu = torch.cuda.device_count()
print(f"Found device: {device_name}, n_gpu: {n_gpu}")
# Out:
# Found device: Tesla P100-PCIE-16GB, n_gpu: 1

# %%
# !pip install transformers
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
print('success!')

import os
import zipfile

data_file = drive.CreateFile({'id': '1zeo8FcaNUnhN660mGMNEAPvxOE4DPOnE'})
data_file.GetContentFile('hw1.zip')

# Extract data from the zipfile and put it into the current directory
with zipfile.ZipFile('hw1.zip', 'r') as zip_file:
    zip_file.extractall('./')
os.remove('hw1.zip')
# We will use hw1 as our working directory
os.chdir('hw1')
print("Data and supporting code downloaded!")

pretrained_models_dir = './pretrained_models_dir'
if not os.path.isdir(pretrained_models_dir):
  os.mkdir(pretrained_models_dir)   # directory to save pretrained models
print('model directory created')

# !pip install -r requirements.txt
print('everything set up!')
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/99/84/7bc03215279f603125d844bf81c3fb3f2d50fe8e511546eb4897e4be2067/transformers-4.0.0-py3-none-any.whl (1.4MB)
#      |████████████████████████████████| 1.4MB 7.8MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.8)
# Collecting tokenizers==0.9.4
#   Downloading https://files.pythonhosted.org/packages/0f/1c/e789a8b12e28be5bc1ce2156cf87cb522b379be9cadc7ad8091a4cc107c4/tokenizers-0.9.4-cp36-cp36m-manylinux2010_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 28.8MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.18.5)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 45.1MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.11.8)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.17.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=a931a5411723480d8fc42a73c1aca3fc92a6d62ba9e38665d3aa462aefc7d5ea
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.43 tokenizers-0.9.4 transformers-4.0.0
# success!
# Data and supporting code downloaded!
# model directory created
# Collecting seqeval
#   Downloading https://files.pythonhosted.org/packages/9d/2d/233c79d5b4e5ab1dbf111242299153f3caddddbb691219f363ad55ce783d/seqeval-1.2.2.tar.gz (43kB)
#      |████████████████████████████████| 51kB 4.7MB/s
# Collecting conllu
#   Downloading https://files.pythonhosted.org/packages/1c/20/39bf21e3a0304c874c40c9cec96e3f70d2ef4b1ada3585f7dbee91dc8c05/conllu-4.2.1-py2.py3-none-any.whl
# Collecting googletrans
#   Downloading https://files.pythonhosted.org/packages/71/3a/3b19effdd4c03958b90f40fe01c93de6d5280e03843cc5adf6956bfc9512/googletrans-3.0.0.tar.gz
# Collecting langdetect
#   Downloading https://files.pythonhosted.org/packages/56/a3/8407c1e62d5980188b4acc45ef3d94b933d14a2ebc9ef3505f22cf772570/langdetect-1.0.8.tar.gz (981kB)
#      |████████████████████████████████| 983kB 13.8MB/s
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from seqeval->-r requirements.txt (line 1)) (1.18.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.6/dist-packages (from seqeval->-r requirements.txt (line 1)) (0.22.2.post1)
# Collecting httpx==0.13.3
#   Downloading https://files.pythonhosted.org/packages/54/b4/698b284c6aed4d7c2b4fe3ba5df1fcf6093612423797e76fbb24890dd22f/httpx-0.13.3-py3-none-any.whl (55kB)
#      |████████████████████████████████| 61kB 8.9MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from langdetect->-r requirements.txt (line 4)) (1.15.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.21.3->seqeval->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from httpx==0.13.3->googletrans->-r requirements.txt (line 3)) (2020.11.8)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.6/dist-packages (from httpx==0.13.3->googletrans->-r requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.6/dist-packages (from httpx==0.13.3->googletrans->-r requirements.txt (line 3)) (2.10)
# Collecting rfc3986<2,>=1.3
#   Downloading https://files.pythonhosted.org/packages/78/be/7b8b99fd74ff5684225f50dd0e865393d2265656ef3b4ba9eaaaffe622b8/rfc3986-1.4.0-py2.py3-none-any.whl
# Collecting httpcore==0.9.*
#   Downloading https://files.pythonhosted.org/packages/dd/d5/e4ff9318693ac6101a2095e580908b591838c6f33df8d3ee8dd953ba96a8/httpcore-0.9.1-py3-none-any.whl (42kB)
#      |████████████████████████████████| 51kB 7.3MB/s
# Collecting hstspreload
#   Downloading https://files.pythonhosted.org/packages/d3/3c/cdeaf9ab0404853e77c45d9e8021d0d2c01f70a1bb26e460090926fe2a5e/hstspreload-2020.11.21-py3-none-any.whl (981kB)
#      |████████████████████████████████| 983kB 27.9MB/s
# Collecting sniffio
#   Downloading https://files.pythonhosted.org/packages/52/b0/7b2e028b63d092804b6794595871f936aafa5e9322dcaaad50ebf67445b3/sniffio-1.2.0-py3-none-any.whl
# Collecting h11<0.10,>=0.8
#   Downloading https://files.pythonhosted.org/packages/5a/fd/3dad730b0f95e78aeeb742f96fa7bbecbdd56a58e405d3da440d5bfb90c6/h11-0.9.0-py2.py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 9.4MB/s
# Collecting h2==3.*
#   Downloading https://files.pythonhosted.org/packages/25/de/da019bcc539eeab02f6d45836f23858ac467f584bfec7a526ef200242afe/h2-3.2.0-py2.py3-none-any.whl (65kB)
#      |████████████████████████████████| 71kB 8.6MB/s
# Collecting contextvars>=2.1; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/83/96/55b82d9f13763be9d672622e1b8106c85acb83edd7cc2fa5bc67cd9877e9/contextvars-2.4.tar.gz
# Collecting hyperframe<6,>=5.2.0
#   Downloading https://files.pythonhosted.org/packages/19/0c/bf88182bcb5dce3094e2f3e4fe20db28a9928cb7bd5b08024030e4b140db/hyperframe-5.2.0-py2.py3-none-any.whl
# Collecting hpack<4,>=3.0
#   Downloading https://files.pythonhosted.org/packages/8a/cc/e53517f4a1e13f74776ca93271caef378dadec14d71c61c949d759d3db69/hpack-3.0.0-py2.py3-none-any.whl
# Collecting immutables>=0.9
#   Downloading https://files.pythonhosted.org/packages/99/e0/ea6fd4697120327d26773b5a84853f897a68e33d3f9376b00a8ff96e4f63/immutables-0.14-cp36-cp36m-manylinux1_x86_64.whl (98kB)
#      |████████████████████████████████| 102kB 9.3MB/s
# Building wheels for collected packages: seqeval, googletrans, langdetect, contextvars
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-cp36-none-any.whl size=16171 sha256=b95f217478e248bac59eb0c0a6a1aa74287783b30c12b465ab497248c3a8e8e0
#   Stored in directory: /root/.cache/pip/wheels/52/df/1b/45d75646c37428f7e626214704a0e35bd3cfc32eda37e59e5f
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.0.0-cp36-none-any.whl size=15736 sha256=9ead323c305e5aaa337fca8b36d602e80d6c4ac85205dfc3a30a1f6e8596419e
#   Stored in directory: /root/.cache/pip/wheels/28/1a/a7/eaf4d7a3417a0c65796c547cff4deb6d79c7d14c2abd29273e
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.8-cp36-none-any.whl size=993195 sha256=77baa42bd5b8f54ee934f1020439a5104d5096aa09a71414568aa580889c6018
#   Stored in directory: /root/.cache/pip/wheels/8d/b3/aa/6d99de9f3841d7d3d40a60ea06e6d669e8e5012e6c8b947a57
#   Building wheel for contextvars (setup.py) ... done
#   Created wheel for contextvars: filename=contextvars-2.4-cp36-none-any.whl size=7666 sha256=69bf82bcf8ca14cb5574f07d53b073a9ea63bb1194d919290f87ff06b8f0e210
#   Stored in directory: /root/.cache/pip/wheels/a5/7d/68/1ebae2668bda2228686e3c1cf16f2c2384cea6e9334ad5f6de
# Successfully built seqeval googletrans langdetect contextvars
# Installing collected packages: seqeval, conllu, rfc3986, h11, immutables, contextvars, sniffio, hyperframe, hpack, h2, httpcore, hstspreload, httpx, googletrans, langdetect
# Successfully installed conllu-4.2.1 contextvars-2.4 googletrans-3.0.0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2020.11.21 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 immutables-0.14 langdetect-1.0.8 rfc3986-1.4.0 seqeval-1.2.2 sniffio-1.2.0
# everything set up!

# %%
# coding=utf-8

import dataclasses
import logging
import math
import os
import timeit
from dataclasses import dataclass, field
from typing import Callable, Dict, List, Tuple, Optional

import numpy as np
from seqeval.metrics import accuracy_score, f1_score, precision_score, recall_score
import torch
from torch.utils.data import DataLoader, SequentialSampler
from tqdm import tqdm

from transformers import (
    AutoConfig,
    AutoModelWithLMHead,
    AutoModelForSequenceClassification,
    AutoModelForQuestionAnswering,
    AutoModelForTokenClassification,
    AutoTokenizer,
    PreTrainedTokenizer,
    EvalPrediction
)
from transformers import (
    GlueDataset,
    SquadDataset,
    LineByLineTextDataset,
    TextDataset,
    DataCollatorForLanguageModeling,
)
from transformers import GlueDataTrainingArguments, SquadDataTrainingArguments
from transformers import (
    Trainer,
    TrainingArguments,
    glue_compute_metrics,
    glue_output_modes,
    glue_tasks_num_labels,
    set_seed,
)
from transformers.data.processors.squad import SquadResult
from transformers.data.metrics.squad_metrics import (
    compute_predictions_logits,
    squad_evaluate,
)
from tasks import NER
from utils_ner import Split, TokenClassificationDataset, TokenClassificationTask

from transformers import glue_processors
from transformers.data.processors.utils import InputExample
from langdetect import detect

logger = logging.getLogger(__name__)


@dataclass
class ModelArguments:
    """
    Arguments pertaining to which model/config/tokenizer we are going to fine-tune from.
    """
    model_type: str = field(
        default="bert",
        metadata={"help": "Model type, e.g., bert."}
    )
    model_name_or_path: str = field(
        default="bert",
        metadata={"help": "Path to pretrained model or model identifier from huggingface.co/models."}
    )
    do_lower_case: Optional[bool] = field(
        default=False,
        metadata={"help": "Whether you want to do lower case on input before tokenization."}
    )
    model_cache_dir: Optional[str] = field(
        default=None,
        metadata={"help": "Where you want to store the pretrained models downloaded from s3."}
    )
    data_cache_dir: Optional[str] = field(
        default=None,
        metadata={"help": "Where you want to store the cached features for the task."}
    )


@dataclass
class NerDataTrainingArguments:
    """
    Arguments pertaining to what data we are going to input our model for training and eval.
    """

    data_dir: str = field(
        metadata={"help": "The input data dir. Should contain data files for the task."}
    )
    labels: Optional[str] = field(
        default=None,
        metadata={"help": "Path to a file containing all labels for the task."},
    )
    max_seq_length: int = field(
        default=128,
        metadata={
            "help": "The maximum total input sequence length after tokenization. Sequences longer "
            "than this will be truncated, sequences shorter will be padded."
        },
    )
    overwrite_cache: bool = field(
        default=False, metadata={"help": "Overwrite the cached training and evaluation sets."}
    )


@dataclass
class LMDataTrainingArguments:
    """
    Arguments pertaining to what data we are going to input our model for training and eval.
    """

    train_data_file: Optional[str] = field(
        default=None, metadata={"help": "The input training data file (a text file)."}
    )
    eval_data_file: Optional[str] = field(
        default=None,
        metadata={"help": "An optional input evaluation data file to evaluate the perplexity on (a text file)."},
    )
    line_by_line: bool = field(
        default=False,
        metadata={"help": "Whether distinct lines of text in the dataset are to be handled as distinct sequences."},
    )

    mlm: bool = field(
        default=False, metadata={"help": "Train with masked-language modeling loss instead of language modeling."}
    )
    mlm_probability: float = field(
        default=0.15, metadata={"help": "Ratio of tokens to mask for masked language modeling loss"}
    )
    block_size: int = field(
        default=-1,
        metadata={
            "help": "Optional input sequence length after tokenization."
            "The training dataset will be truncated in block of this size for training."
            "Default to the model max input length for single sentence inputs (take into account special tokens)."
        },
    )
    overwrite_cache: bool = field(
        default=False, metadata={"help": "Overwrite the cached training and evaluation sets"}
    )


def get_dataset(
    args: LMDataTrainingArguments,
    tokenizer: PreTrainedTokenizer,
    evaluate: bool = False,
    cache_dir: Optional[str] = None,
):
    file_path = args.eval_data_file if evaluate else args.train_data_file
    if args.line_by_line:
        return LineByLineTextDataset(tokenizer=tokenizer, file_path=file_path, block_size=args.block_size)
    else:
        return TextDataset(
            tokenizer=tokenizer,
            file_path=file_path,
            block_size=args.block_size,
            overwrite_cache=args.overwrite_cache,
            cache_dir=cache_dir,
        )


DATA_TRAINING_ARGUMENTS = {
    "text_classification": GlueDataTrainingArguments,
    "question_answering": SquadDataTrainingArguments,
    "sequence_labeling": NerDataTrainingArguments,
}


AUTO_MODEL = {
    "text_classification": AutoModelForSequenceClassification,
    "question_answering": AutoModelForQuestionAnswering,
    "sequence_labeling": AutoModelForTokenClassification,
}


DATASET = {
    "text_classification": GlueDataset,
    "question_answering": SquadDataset,
    "sequence_labeling": TokenClassificationDataset,
}


# some functions for fine-tuning BERT on a downstream target task
def do_target_task_finetuning(model_name_or_path, task_type, output_dir, **kwargs):
    r""" Fine-tuning BERT on a downstream target task.
    Params:
        **model_name_or_path**: either:
            - a string with the `shortcut name` of a pre-trained model configuration to load from cache
                or download and cache if not already stored in cache (e.g. 'bert-base-uncased').
            - a path to a `directory` containing a configuration file saved
                using the `save_pretrained(save_directory)` method.
            - a path or url to a saved configuration `file`.
        **task_type**: string:
            The class of the task to train, selected in
            ["text_classification", "question_answering", "sequence_labeling"].
        **output_dir**: string:
            The output directory where the model predictions and checkpoints will be written.
        **kwargs**: (`optional`) dict:
            Dictionary of key/value pairs with which to update the configuration object after loading.
            - The values in kwargs of any keys which are configuration attributes will be used
            to override the loaded values.
    """
    # See all possible arguments in src/transformers/training_args.py

    assert task_type in DATA_TRAINING_ARGUMENTS
    model_args = ModelArguments(model_name_or_path=model_name_or_path)
    data_args_params = {}
    for param in ["task_name", "data_dir"]:
        if param in kwargs:
            data_args_params.update({param: kwargs[param]})

    data_args = DATA_TRAINING_ARGUMENTS[task_type](**data_args_params)
    training_args = TrainingArguments(output_dir=output_dir)

    # override the loaded configs
    configs = (model_args, data_args, training_args)
    for config in configs:
        for key, value in kwargs.items():
            if hasattr(config, key):
                setattr(config, key, value)

    if (
        os.path.exists(training_args.output_dir)
        and os.listdir(training_args.output_dir)
        and training_args.do_train
        and not training_args.overwrite_output_dir
    ):
        raise ValueError(
            f"Output directory ({training_args.output_dir}) already exists and is not empty. "
            f"Use --overwrite_output_dir to overcome."
        )

    for p in [model_args.model_cache_dir, model_args.data_cache_dir, training_args.output_dir]:
        if not os.path.exists(p):
            os.makedirs(p)

    # Setup logging
    logging.basicConfig(
        format="%(asctime)s - %(levelname)s - %(name)s -   %(message)s",
        datefmt="%m/%d/%Y %H:%M:%S",
        level=logging.INFO,
    )

    logger.info("Process device: %s, n_gpu: %s", training_args.device, training_args.n_gpu)
    logger.info("Training/evaluation parameters %s", training_args)


    # Set seed
    set_seed(training_args.seed)

    if task_type == "text_classification":
        try:
            data_args.task_name = data_args.task_name.lower()
            num_labels = glue_tasks_num_labels[data_args.task_name]
            output_mode = glue_output_modes[data_args.task_name]
        except KeyError:
            raise ValueError("Task not found: %s" % (data_args.task_name))
    elif task_type == "sequence_labeling":
        token_classification_task = NER() # You might want to this to Chunk() or POS()
        # if you are working with a Chunk or POS task, respectively
        labels = token_classification_task.get_labels(data_args.labels)
        label_map: Dict[int, str] = {i: label for i, label in enumerate(labels)}
        num_labels = len(labels)

    # Load pretrained model and tokenizer

    AutoModel = AUTO_MODEL[task_type]
    auto_config_params = {
        'pretrained_model_name_or_path': model_args.model_name_or_path,
        'cache_dir': model_args.model_cache_dir,
    }

    if task_type == "text_classification":
        auto_config_params.update({
            "num_labels": num_labels,
            "finetuning_task": data_args.task_name,
        })
    elif task_type == "sequence_labeling":
        auto_config_params.update({
            "num_labels": num_labels,
            "id2label": label_map,
            "label2id": {label: i for i, label in enumerate(labels)},
        })

    config = AutoConfig.from_pretrained(**auto_config_params)

    auto_tokenizer_params = {
        "pretrained_model_name_or_path": model_args.model_name_or_path,
        "cache_dir": model_args.model_cache_dir,
        "do_lower_case": model_args.do_lower_case,
    }
    tokenizer = AutoTokenizer.from_pretrained(**auto_tokenizer_params)

    auto_model_params = {
        "pretrained_model_name_or_path": model_args.model_name_or_path,
        "from_tf": False,
        "config": config,
        "cache_dir": model_args.model_cache_dir,
    }

    if "model_load_mode" in kwargs and kwargs["model_load_mode"] == "base_model_only":
        WEIGHTS_NAME = "pytorch_model.bin"
        archive_file = os.path.join(model_args.model_name_or_path, WEIGHTS_NAME)
        # Use torch.load with map_location=torch.device() to map the pretrained model to our device.
        model_state_dict = torch.load(archive_file, map_location=torch.device(training_args.device))
        
        state_dict_with_prefix = {}
        for key, value in model_state_dict.items():
            if key.startswith(model_args.model_type):
                state_dict_with_prefix[key] = value

        auto_model_params.update({"state_dict": state_dict_with_prefix})
        
    model = AutoModel.from_pretrained(**auto_model_params)

    # Get datasets
    Dataset = DATASET[task_type]
    dataset_params = {
        "tokenizer": tokenizer,
    }
    if task_type == "sequence_labeling":
        dataset_params.update({
            "token_classification_task": token_classification_task,
            "data_dir": data_args.data_dir,
            "labels": labels,
            "model_type": model_args.model_type,
            "max_seq_length": data_args.max_seq_length
        })

    else:
        dataset_params.update({
            "args": data_args,
            "cache_dir": model_args.data_cache_dir,
        })

    train_dataset = (Dataset(**dataset_params) if training_args.do_train else None)

    dataset_params.update({"mode": Split.dev if task_type == "sequence_labeling" else "dev"})
    eval_dataset = (Dataset(**dataset_params) if training_args.do_eval else None)

    # Initialize our Trainer
    trainer_params = {
        "model": model,
        "args": training_args,
        "train_dataset": train_dataset,
        "eval_dataset": eval_dataset,
    }
    trainer = Trainer(**trainer_params)

    # Training
    if training_args.do_train:
        trainer.train(
            model_path=model_args.model_name_or_path if os.path.isdir(model_args.model_name_or_path) else None
        )
        trainer.save_model()
        # For convenience, we also re-save the tokenizer to the same directory
        tokenizer.save_pretrained(training_args.output_dir)

    # Evaluation
    eval_results = {}
    if training_args.do_eval:
        if task_type == "text_classification":
            def build_compute_metrics_fn(task_name: str) -> Callable[[EvalPrediction], Dict]:
                def compute_metrics_fn(p: EvalPrediction):
                    if output_mode == "classification":
                        preds = np.argmax(p.predictions, axis=1)
                    elif output_mode == "regression":
                        preds = np.squeeze(p.predictions)
                    return glue_compute_metrics(task_name, preds, p.label_ids)
                return compute_metrics_fn

            logger.info("*** Evaluate ***")
            # Loop to handle MNLI double evaluation (matched, mis-matched)
            eval_datasets = [eval_dataset]
            if data_args.task_name == "mnli":
                mnli_mm_data_args = dataclasses.replace(data_args, task_name="mnli-mm")
                eval_datasets.append(
                    Dataset(mnli_mm_data_args, tokenizer=tokenizer, mode="dev", cache_dir=model_args.data_cache_dir)
                )

            for eval_dataset in eval_datasets:
                trainer.compute_metrics = build_compute_metrics_fn(eval_dataset.args.task_name)
                eval_result = trainer.evaluate(eval_dataset=eval_dataset)

                output_eval_file = os.path.join(training_args.output_dir, f"eval_results.txt")
                with open(output_eval_file, "w") as writer:
                    logger.info("***** Eval results *****")
                    for key, value in eval_result.items():
                        logger.info("  %s = %s", key, value)
                        writer.write("%s = %s\n" % (key, value))

                eval_results.update(eval_result)

        elif task_type == "question_answering":
            # We don't use trainer.evaluate here since it currently does not support question answering tasks
            # (https://github.com/huggingface/transformers/issues/7032)
            model = AutoModel.from_pretrained(model_args.model_cache_dir)
            tokenizer = AutoTokenizer.from_pretrained(model_args.model_cache_dir, do_lower_case=model_args.do_lower_case)
            model.to(training_args.device)


            dataset = eval_dataset.dataset
            examples = eval_dataset.examples
            features = eval_dataset.features
            eval_batch_size = training_args.per_gpu_eval_batch_size * max(1, training_args.n_gpu)

            eval_sampler = SequentialSampler(dataset)
            eval_dataloader = DataLoader(dataset, sampler=eval_sampler, batch_size=eval_batch_size)

            logger.info("*** Evaluate ***")
            description = "Evaluation"
            logger.info("***** Running %s *****", description)
            logger.info("  Num examples = %d", len(dataset))
            logger.info("  Batch size = %d", eval_batch_size)

            all_results = []
            start_time = timeit.default_timer()

            for batch in tqdm(eval_dataloader, desc=description):
                model.eval()
                batch = tuple(t.to(training_args.device) for t in batch)

                with torch.no_grad():
                    inputs = {
                        "input_ids": batch[0],
                        "attention_mask": batch[1],
                        "token_type_ids": batch[2],
                    }
                    feature_indices = batch[3]
                    outputs = model(**inputs)

                for i, feature_index in enumerate(feature_indices):
                    eval_feature = features[feature_index.item()]
                    unique_id = int(eval_feature.unique_id)
                    output = [output[i].detach().cpu().tolist() for output in outputs]
                    start_logits, end_logits = output
                    result = SquadResult(unique_id, start_logits, end_logits)
                    all_results.append(result)

            evalTime = timeit.default_timer() - start_time
            logger.info("  Evaluation done in total %f secs (%f sec per example)", evalTime, evalTime / len(dataset))

            # Compute predictions
            output_prediction_file = os.path.join(training_args.output_dir, "predictions.json")
            output_nbest_file = os.path.join(training_args.output_dir, "nbest_predictions.json")

            output_null_log_odds_file = os.path.join(training_args.output_dir, "null_odds.json") \
                if data_args.version_2_with_negative else None

            predictions = compute_predictions_logits(
                all_examples=examples,
                all_features=features,
                all_results=all_results,
                n_best_size=data_args.n_best_size,
                max_answer_length=data_args.max_answer_length,
                do_lower_case=model_args.do_lower_case,
                output_prediction_file=output_prediction_file,
                output_nbest_file=output_nbest_file,
                output_null_log_odds_file=output_null_log_odds_file,
                verbose_logging=False,
                version_2_with_negative=data_args.version_2_with_negative,
                null_score_diff_threshold=data_args.null_score_diff_threshold,
                tokenizer=tokenizer,
            )

            # Compute the F1 and exact scores.
            eval_result = squad_evaluate(examples, predictions)

            output_eval_file = os.path.join(training_args.output_dir, f"eval_results.txt")
            with open(output_eval_file, "w") as writer:
                logger.info("***** Eval results *****")
                for key, value in eval_result.items():
                    logger.info("  %s = %s", key, value)
                    writer.write("%s = %s\n" % (key, value))

            eval_results.update(eval_result)


        elif task_type == "sequence_labeling":
            def align_predictions(predictions: np.ndarray, label_ids: np.ndarray) -> Tuple[List[int], List[int]]:
                preds = np.argmax(predictions, axis=2)
                batch_size, seq_len = preds.shape
                label_list = [[] for _ in range(batch_size)]
                pred_list = [[] for _ in range(batch_size)]

                for i in range(batch_size):
                    for j in range(seq_len):
                        if label_ids[i, j] != torch.nn.CrossEntropyLoss().ignore_index:
                            label_list[i].append(label_map[label_ids[i][j]])
                            pred_list[i].append(label_map[preds[i][j]])
                return pred_list, label_list

            def compute_metrics_fn(p: EvalPrediction) -> Dict:
                pred_list, label_list = align_predictions(p.predictions, p.label_ids)
                return {
                    "accuracy_score": accuracy_score(label_list, pred_list),
                    "precision": precision_score(label_list, pred_list),
                    "recall": recall_score(label_list, pred_list),
                    "f1": f1_score(label_list, pred_list),
                }

            trainer.compute_metrics = compute_metrics_fn
            eval_result = trainer.evaluate(eval_dataset=eval_dataset)

            output_eval_file = os.path.join(training_args.output_dir, f"eval_results.txt")
            with open(output_eval_file, "w") as writer:
                logger.info("***** Eval results *****")
                for key, value in eval_result.items():
                    logger.info("  %s = %s", key, value)
                    writer.write("%s = %s\n" % (key, value))

            eval_results.update(eval_result)

        else:
            raise ValueError("Invalid task type.")
    return eval_results


print('setup complete')
# Out:
# setup complete

# %%
data_file = drive.CreateFile({'id': '19cnGSN88KlRJRcIqwxw3C4ylJftdkZ2W'})
data_file.GetContentFile('bert-base-cased-finetuned-squad.zip')

# Extract the data from the zipfile and put it into pretrained_models_dir
with zipfile.ZipFile('bert-base-cased-finetuned-squad.zip', 'r') as zip_file:
    zip_file.extractall(pretrained_models_dir)
os.remove('bert-base-cased-finetuned-squad.zip')
print("bert-base-cased-finetuned-squad downloaded!")
# Out:
# bert-base-cased-finetuned-squad downloaded!

# %%
import torch.nn as nn
from torch import sigmoid
import torch.nn.functional as F
import numpy as np

from sklearn.metrics import accuracy_score

def train(model, x, y, optimizer, criterion): 
    model.zero_grad()
    output = model(x)
    loss = criterion(output, y)
    loss.backward()
    optimizer.step()
    return loss, output

def eval(model, x, y=None, criterion=None):
    output = model(x)
    loss = 0
    if y is not None:
        loss = criterion(output, y)
    return loss, output

class Network2(nn.Module):
    def __init__(self):
        super().__init__()
        self.dropout_layer = nn.Dropout(p=0.1) 
        self.fully_connected = nn.Linear(768, 1)      

    def forward(self,x):
        x = self.dropout_layer(x)
        x = self.fully_connected(x)
        x = sigmoid(x) 
        return x

    def predict_label(self,pred):
        ans = []
        for t in pred:
            ans.append(np.round(t.detach()))
        return torch.tensor(ans)

# %%
from torch.optim import Adam

net_model = Network2()
criterion = nn.BCELoss()
optm = Adam(net_model.parameters(), lr = 5e-4)

net_model = torch.load("/content/classifier_BERT.pt")

# %%
from transformers import BertTokenizerFast, AutoModel

model_name_or_path = "bert-base-uncased"
cache_dir = os.path.join(pretrained_models_dir, model_name_or_path)
tokenizer = BertTokenizerFast.from_pretrained(model_name_or_path, add_special_tokens=False)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_Bert = AutoModel.from_pretrained(model_name_or_path, cache_dir=cache_dir)
model_Bert = model_Bert.to(device)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=440473133.0, style=ProgressStyle(descri…

# %%
def convert_into_words (sent) :  
  word_with_offset = []
  start = end = 0
  w = ''
  for i in range(len(sent)):
      if sent[i] == ' ':
          if(w != '') :
            word_with_offset.append([start,end,w])
          start = i + 1
          w = ''
      else:
          w = w + sent[i]
      end = end + 1

  # last word always ends without space
  if(w != '') :
    word_with_offset.append([start,end,w])

  return word_with_offset


def getEmbeddings (sent) :
  # Encode the input sentence and get the model's output
  input = tokenizer.encode(sent, return_tensors="pt",add_special_tokens=False).to(device)

  num_tokens = len(input[0])
  
  if num_tokens >= 512 :
    return None, True

  temp = tokenizer.encode_plus(sent,return_offsets_mapping=True, add_special_tokens=False, return_tensors="pt").to(device)
  input_offset = temp['offset_mapping'][0]
  input_tokens = tokenizer.tokenize(sent,return_tensors="pt")

  # The model outputs the masked language modeling logits of shape 
  # [batch_size, sequence_length, vocab_size] 
  token_logits = model_Bert(input)[0]

  token_with_offset = []  
  for i in range(len(input_offset)) :
    token_with_offset.append( [input_offset[i][0], input_offset[i][1], input_tokens[i]] )

  tind = 0
  output_emb = []

  word_with_offset = convert_into_words(sent)

  for v in word_with_offset :
    cur_word = v[2]
    flag = True
    while(flag) :
      if(v[0] == token_with_offset[tind][0]) :
        #print(cur_word,token_with_offset[tind])
        output_emb.append([cur_word,tind])
        flag = False
      tind += 1

  ret_word_embedding = []

  for token_pair in output_emb :
    word = token_pair[0]
    word_embedding = token_logits[0][token_pair[1]]
    # word_embedding = word_embedding.reshape([1, word_embedding.shape[0]])
    ret_word_embedding.append([word, word_embedding])

  return ret_word_embedding , False

# %%
cur_sentence = "[CLS] what is throat cancer ? [SEP] is it treatable ?"
em = getEmbeddings(cur_sentence)
em = em[0]
for e in em:
    net_model = net_model.eval()        
    loss, output = eval(net_model, e[1])
    y_pred = net_model.predict_label(output.cpu())
    print(e[0],y_pred)
# Out:
# [CLS] tensor([0.])
# what tensor([0.])
# is tensor([0.])
# throat tensor([0.])
# cancer tensor([1.])
# ? tensor([0.])
# [SEP] tensor([0.])
# is tensor([0.])
# it tensor([0.])
# treatable tensor([0.])
# ? tensor([0.])

# %%
def getRelevantWords(full=None, history = None, cur=None): # either give full sentence, or give cur question + history
    if full is None:
        full = "[CLS] " + history + " [SEP] " + cur
    else:
        full = "[CLS] " + full

    all_words = full.split(' ')
    em = getEmbeddings(full)
    em = em[0]
    em = em[1:]
    
    rel_words = []
    rel_phrase = ""
    for e in em:     
      loss, output = eval(net_model, e[1])
      y_pred = net_model.predict_label(output.cpu())      
      if(y_pred == 1) :
        rel_words.append(e[0])
        rel_phrase += " "+e[0]
      if(e[0] == "[SEP]") :
        break  

    return rel_words, rel_phrase

# %%
cur_sentence = "what is throat cancer ? [SEP] is it treatable ?"
temp,temp_phrase = getRelevantWords(cur_sentence)
print(temp,temp_phrase)
# Out:
# ['cancer']  cancer

# %%
with open("/content/coref_answers_10.txt") as f :
  passages_list = f.readlines()
passages_list = [x.strip() for  x in passages_list]

question_passage_map = {}
for p in passages_list:
    parts = p.split('\t')
    if parts[0] not in question_passage_map:
        question_passage_map[parts[0]] = [' '.join(parts[1:])]
    else:
        question_passage_map[parts[0]].append(' '.join(parts[1:]))

print(question_passage_map['76_2'])
# Out:
# ['Traditional Differences Between Genre and Literary Fiction. The traditional differences between genre and literary fiction are outlined in the table below. Keep in mind these are broad-brush differences that in some cases focus on the extremes of the categories and that disagreements abound. Many genre books have elements of literary fiction and vice versa and there is increasingly a third category of crossover fiction that will be discussed below.', 'Literary Devices, Elements, Techniques, and Terms. A literary devise is any tool used in literature to help the reader understand the story and its character(s). There are two types of literary devises used by authors, literary elements and literary techniques. Literary elements. provide structure to the literature. All literary elements are evident in all literature that creates a story. Literary techniques. are specific to each author.', 'Bourdieu\'s principle of habitus is interwoven with the concept of structuralism in literary theory. Peter Barry explains, "in the structuralist approach to literature there is a constant movement away from interpretation of the individual literary work and a parallel drive towards understanding the larger structures which contain them" (2009, p. 39). There is therefore a strong desire to understand the larger influencing factors which makes an individual literary work. As Bourdieu explains, habitus "are structured structures, generative principles of distinct and distinctive practices – what the worker eats, and especially the way he eats it, the sport he practices and the way he practices it, his political opinions and the way he expresses them are systematically different from the industrial proprietor\'s corresponding activities / habitus are also structuring structures, different classifying schemes classification principles, different principles of vision and division, different tastes. Habitus make different differences; they implement distinctions between what is good and what is bad, what is right and what is wrong, between what is distinguished and what is vulgar, and so on, but they are not the same. Thus, for instance, the same behaviour or even the same good can appear distinguished to one person, pretentious to someone else, and cheap or showy to yet another" (Bourdieu, 1996). As a result, habitus may be employed in literary theory in order to understand those larger, external structures which influence individual theories and works of literature.', 'We will explore the difference between literary elements and literary techniques, and look at examples and definitions of several popular literary terms. Weâ\x80\x99ll also look at how these literary devices function in two popular works, Shakespeareâ\x80\x99s Hamlet and The Great Gatsby by F. Scott Fitzgerald.', 'Other techniques, however, are more intentional, such as foreshadowing and red herrings. We will explore the difference between literary elements and literary techniques, and look at examples and definitions of several popular literary terms. Weâ\x80\x99ll also look at how these literary devices function in two popular works, Shakespeareâ\x80\x99s Hamlet and The Great Gatsby by F. Scott Fitzgerald.', 'LITERARY ELEMENTS Below is a list of Literary Elements, or the parts of a story. When you examine and analyze your literary work for class presentation, ask the following questions.They will help you find the literary elements of your story.ITERARY ELEMENTS Below is a list of Literary Elements, or the parts of a story. When you examine and analyze your literary work for class presentation, ask the following questions.', 'In fact, the differences between dialects of modern spoken Welsh pale into insignificance compared to the difference between some forms of the spoken language and the most formal constructions of the literary language. The latter is considerably more conservative and is the language used in Welsh translations of the Bible, amongst other things (although the  ...

# %%
coref_questions = []
with open("/content/evaluation_topics_annotated_resolved_v1.0.tsv") as f :
  temp = f.readlines()

question_ids = []
for t in temp :
  te = t.split('\t')
  coref_questions.append(te[1].strip())
  question_ids.append(te[0].strip())

print(len(coref_questions))
print(coref_questions)

print(len(question_ids))
print(question_ids)
# Out:
# 479
# ['What is throat cancer?', 'Is throat cancer treatable?', 'Tell me about lung cancer.', "What are lung cancer's symptoms?", 'Can lung cancer spread to the throat?', 'What causes throat cancer?', 'What is the first sign of throat cancer?', 'Is throat cancer the same as esophageal cancer?', "What's the difference in throat cancer and esophageal cancer's symptoms?", 'What are the different types of sharks?', 'Are sharks endangered? If so, which species?', 'Tell me more about tiger sharks.', 'What is the largest shark ever to have lived on Earth?', "What's the biggest shark ever caught?", 'What about for great whites?', 'Tell me about Mako sharks.', 'What are Mako shark adaptations?', 'Where do Mako sharks live?', 'What do Mako sharks eat?', 'How do Mako sharks compare with Tiger sharks for being dangerous?', 'Tell me about the Neverending Story film.', 'What is the Neverending Story film about?', 'How was the Neverending Story film received?', 'Did the Neverending Story film win any awards?', 'Was the Neverending Story film a book first?', 'Who was the author and when was the Neverending Story film published?', 'What are the main themes of the Neverending Story film?', 'Who are the main characters of the the Neverending Story film?', 'What are the differences between the book and movies of the the Neverending Story?', 'Did the horse Artax really die?', 'Tell me about the Bronze Age collapse.', 'What is the evidence for the Bronze Age collapse?', 'What are some of the possible causes of the Bronze Age collapse?', 'Who were the Sea Peoples during the Bronze Age collapse?', 'What was their role in the Bronze Age collapse?', 'What other factors led to a breakdown of trade during the Bronze Age collapse?', 'What about environmental factors during the Bronze Age collapse?', 'What empires survived the Bronze Age collapse?', 'What came after the Bronze Age collapse?', 'Tell me about the history of toilets.', 'Where does the term toilet come from?', 'Where and when was the first toilet invented?', 'Why do the Brits call a toilet a loo?', 'What came before toilets?', 'When did indoor versions of toilets become common?', 'How many types of toilets are there?', 'Why are toilets so important for society?', 'What is the role of toilets in film?', 'What is the US Electoral College?', 'How does the US Electoral College work?', 'Tell me about the US Electoral College creation.', 'Why was the US Electoral College system chosen?', 'How has the US Electoral College changed over time?', "What if the electors don't vote for the pledged candidate?", "How have electors that don't vote for the pledged candidate changed election outcomes?", 'Who are the Hamilton Electors and what were the Hamilton Electors trying to do?', 'How would the US Electoral College be abolished?', 'How does the National Popular Vote Interstate Compact work?', 'Is the National Popular Vote Interstate Compact legal?', 'What was the Stanford Experiment?', 'What did the Stanford Experiment show?', 'Tell me about the author of the Stanford Experiment.', 'Was the Stanford Experiment ethical?', 'What are other similar experiments to the Stanford Experiment?', 'What happened in the Milgram experiment?', 'Why was the Milgram experiment important?', 'What were the similarities and differences between the Stanford Experiment and the Milgram experiment?', 'What about the BBC experiment?', 'What are the key findings of the BBC experiment?', 'How did the results of the BBC experiment differ from the Milgram experiment?', 'Why was the BBC experiment ended?', 'What is Lyme disease?', 'How do you get Lyme Disease?', 'How does Lyme Disease make you feel?', 'What happens if Lyme Disease goes untreated?', 'Can Lyme Disease kill you?', 'How reliable is the Lyme Disease test?', 'Can Lyme Disease be cured?', 'What is Chronic Lyme?', 'What does it mean to be a vegan?', 'What is the environmental argument for being a vegan?', 'Do you need milk for strong bones?', 'What are other good sources of calcium b ...
# 479
# ['31_1', '31_2', '31_3', '31_4', '31_5', '31_6', '31_7', '31_8', '31_9', '32_1', '32_2', '32_3', '32_4', '32_5', '32_6', '32_7', '32_8', '32_9', '32_10', '32_11', '33_1', '33_2', '33_3', '33_4', '33_5', '33_6', '33_7', '33_8', '33_9', '33_10', '34_1', '34_2', '34_3', '34_4', '34_5', '34_6', '34_7', '34_8', '34_9', '35_1', '35_2', '35_3', '35_4', '35_5', '35_6', '35_7', '35_8', '35_9', '36_1', '36_2', '36_3', '36_4', '36_5', '36_6', '36_7', '36_8', '36_9', '36_10', '36_11', '37_1', '37_2', '37_3', '37_4', '37_5', '37_6', '37_7', '37_8', '37_9', '37_10', '37_11', '37_12', '38_1', '38_2', '38_3', '38_4', '38_5', '38_6', '38_7', '38_8', '39_1', '39_2', '39_3', '39_4', '39_5', '39_6', '39_7', '39_8', '39_9', '40_1', '40_2', '40_3', '40_4', '40_5', '40_6', '40_7', '40_8', '40_9', '40_10', '41_1', '41_2', '41_3', '41_4', '41_5', '41_6', '41_7', '41_8', '41_9', '42_1', '42_2', '42_3', '42_4', '42_5', '42_6', '42_7', '42_8', '43_1', '43_2', '43_3', '43_4', '43_5', '43_6', '43_7', '43_8', '44_1', '44_2', '44_3', '44_4', '44_5', '44_6', '44_7', '44_8', '45_1', '45_2', '45_3', '45_4', '45_5', '45_6', '45_7', '45_8', '46_1', '46_2', '46_3', '46_4', '46_5', '46_6', '46_7', '46_8', '46_9', '46_10', '47_1', '47_2', '47_3', '47_4', '47_5', '47_6', '47_7', '48_1', '48_2', '48_3', '48_4', '48_5', '48_6', '48_7', '48_8', '48_9', '49_1', '49_2', '49_3', '49_4', '49_5', '49_6', '49_7', '49_8', '49_9', '49_10', '50_1', '50_2', '50_3', '50_4', '50_5', '50_6', '50_7', '50_8', '50_9', '50_10', '51_1', '51_2', '51_3', '51_4', '51_5', '51_6', '51_7', '51_8', '51_9', '51_10', '52_1', '52_2', '52_3', '52_4', '52_5', '52_6', '52_7', '52_8', '52_9', '52_10', '53_1', '53_2', '53_3', '53_4', '53_5', '53_6', '53_7', '53_8', '53_9', '54_1', '54_2', '54_3', '54_4', '54_5', '54_6', '54_7', '54_8', '54_9', '55_1', '55_2', '55_3', '55_4', '55_5', '55_6', '55_7', '55_8', '55_9', '55_10', '56_1', '56_2', '56_3', '56_4', '56_5', '56_6', '56_7', '56_8', '57_1', '57_2', '57_3', '57_4', '57_5', '57_6', '57_7', '57_8', '57_9', '57_10', '58_1', '58_2', '58_3', '58_4', '58_5', '58_6', '58_7', '58_8', '59_1', '59_2', '59_3', '59_4', '59_5', '59_6', '59_7', '59_8', '60_1', '60_2', '60_3', '60_4', '60_5', '60_6', '60_7', '61_1', '61_2', '61_3', '61_4', '61_5', '61_6', '61_7', '61_8', '61_9', '62_1', '62_2', '62_3', '62_4', '62_5', '62_6', '62_7', '62_8', '62_9', '62_10', '62_11', '63_1', '63_2', '63_3', '63_4', '63_5', '63_6', '63_7', '63_8', '63_9', '63_10', '64_1', '64_2', '64_3', '64_4', '64_5', '64_6', '64_7', '64_8', '64_9', '64_10', '64_11', '65_1', '65_2', '65_3', '65_4', '65_5', '65_6', '65_7', '65_8', '65_9', '65_10', '66_1', '66_2', '66_3', '66_4', '66_5', '66_6', '66_7', '66_8', '66_9', '67_1', '67_2', '67_3', '67_4', '67_5', '67_6', '67_7', '67_8', '67_9', '67_10', '67_11', '68_1', '68_2', '68_3', '68_4', '68_5', '68_6', '68_7', '68_8', '68_9', '68_10', '68_11', '69_1', '69_2', '69_3', '69_4', '69_5', '69_6', '69_7', '69_8', '69_9', '69_10', '70_1', '70_2', '70_3', '70_4', '70_5', '70_6', '70_7', '70_8', '70_9', '70_10', '71_1', '71_2', '71_3', '71_4', '71_5', '71_6', '71_7', '71_8', '71_9', '71_10', '71_11', '71_12', '72_1', '72_2', '72_3', '72_4', '72_5', '72_6', '72_7', '72_8', '72_9', '72_10', '73_1', '73_2', '73_3', '73_4', '73_5', '73_6', '73_7', '73_8', '73_9', '73_10', '74_1', '74_2', '74_3', '74_4', '74_5', '74_6', '74_7', '74_8', '74_9', '74_10', '74_11', '74_12', '75_1', '75_2', '75_3', '75_4', '75_5', '75_6', '75_7', '75_8', '75_9', '75_10', '76_1', '76_2', '76_3', '76_4', '76_5', '76_6', '76_7', '76_8', '76_9', '76_10', '77_1', '77_2', '77_3', '77_4', '77_5', '77_6', '77_7', '77_8', '77_9', '77_10', '78_1', '78_2', '78_3', '78_4', '78_5', '78_6', '78_7', '78_8', '78_9', '78_10', '79_1', '79_2', '79_3', '79_4', '79_5', '79_6', '79_7', '79_8', '79_9', '80_1', '80_2', '80_3', '80_4', '80_5', '80_6', '80_7', '80_8', '80_9', '80_10']

# %%
task_name = "SQuAD"
model_name_or_path = "bert-base-cased-finetuned-squad"
pretrained_weights = os.path.join(pretrained_models_dir, model_name_or_path)
task_type = "question_answering"
model = AUTO_MODEL[task_type].from_pretrained(pretrained_weights)
tokenizer = AutoTokenizer.from_pretrained(pretrained_weights)

accepted_answers = []

for i in range(len(coref_questions)):
    question = coref_questions[i]
    context = question_passage_map[question_ids[i]]
    print(len(context))

    flag_found = False
    for j in range(len(context)):
        inputs = tokenizer.encode_plus(question, context[j], add_special_tokens=True, return_tensors="pt", max_length = 512, truncation=True)
        input_ids = inputs["input_ids"].tolist()[0]   
        output = model(**inputs) 
            
        start_logits = output['start_logits']
        end_logits = output['end_logits']   

        max_start , start_ind = torch.topk(start_logits,1)
        max_end , end_ind = torch.topk(end_logits,1)

        output_ids = input_ids[start_ind:end_ind+1]
        output_tokens = tokenizer.convert_ids_to_tokens(output_ids)
        output_string = tokenizer.convert_tokens_to_string(output_tokens)
        
        print(question)
        print(output_string)
        print()

        if output_string != '[CLS]' and output_string != '':
            accepted_answers.append(output_string)
            flag_found = True
            break

    if not flag_found:
        accepted_answers.append('')
# Out:
# Streaming output truncated to the last 5000 lines.
# What is a DC half smoke?
# [CLS]
#
# What is a DC half smoke?
# [CLS]
#
# 10
# Tell me about DC half smoke's history.
# [CLS]
#
# Tell me about DC half smoke's history.
# [CLS]
#
# Tell me about DC half smoke's history.
# [CLS]
#
# Tell me about DC half smoke's history.
# [CLS]
#
# Tell me about DC half smoke's history.
# [CLS]
#
# Tell me about DC half smoke's history.
# [CLS]
#
# Tell me about DC half smoke's history.
# [CLS]
#
# Tell me about DC half smoke's history.
# [CLS]
#
# Tell me about DC half smoke's history.
# [CLS]
#
# Tell me about DC half smoke's history.
# [CLS]
#
# 10
# Describe the oceanic crust.
# [CLS]
#
# Describe the oceanic crust.
# [CLS]
#
# Describe the oceanic crust.
# [CLS]
#
# Describe the oceanic crust.
# [CLS]
#
# Describe the oceanic crust.
# [CLS]
#
# Describe the oceanic crust.
# [CLS]
#
# Describe the oceanic crust.
# [CLS]
#
# Describe the oceanic crust.
# [CLS]
#
# Describe the oceanic crust.
# [CLS]
#
# Describe the oceanic crust.
# [CLS]
#
# 10
# What are the main layers in the oceanic crust?
# crust, mantle and core
#
# 10
# How does the oceanic crust differ from the continental crust?
# thinner and denser
#
# 10
# Which of the oceanic crust and the continental crust is younger and why?
# [CLS]
#
# Which of the oceanic crust and the continental crust is younger and why?
# [CLS]
#
# Which of the oceanic crust and the continental crust is younger and why?
# [CLS] which of the oceanic crust and the continental crust is younger and why? [SEP] continental crust is lighter ( less dense ) than oceanic crust. continental crust is granitic. oceanic crust is basaltic. oceanic crust subducts under a less dense crust whether it's oceanic or continental. continental crust does not subduct. oceanic crust is much younger in geologic age
#
# 10
# Where is the youngest oceanic crust found?
# along spreading centers
#
# 10
# Where is the oldest oceanic crust found?
#
#
# Where is the oldest oceanic crust found?
# [CLS]
#
# Where is the oldest oceanic crust found?
#
#
# Where is the oldest oceanic crust found?
# [CLS]
#
# Where is the oldest oceanic crust found?
# [CLS]
#
# Where is the oldest oceanic crust found?
# [CLS]
#
# Where is the oldest oceanic crust found?
# atlantic ocean
#
# 10
# What is seafloor spreading?
# [CLS]
#
# What is seafloor spreading?
# [CLS]
#
# What is seafloor spreading?
# [CLS]
#
# What is seafloor spreading?
# [CLS]
#
# What is seafloor spreading?
# [CLS]
#
# What is seafloor spreading?
# continental drift
#
# 10
# What is the significance of seafloor spreading?
#
#
# What is the significance of seafloor spreading?
# [CLS]
#
# What is the significance of seafloor spreading?
# [CLS] what is the significance of seafloor spreading? [SEP] the pacific plate subducts in the ibm trench, so understanding what is subducted beneath ibm requires understanding the history of the western pacific. the ibm arc system subducts mid - jurassic to early cretaceous lithosphere, with younger lithosphere in the north and older lithosphere in the south. it is not possible to directly know the composition of subducted materials presently being processed by the ibm subduction factory – what is now 130 km deep in the subduction zone entered the trench 4 – 10 million years ago. however, the composition of the western pacific seafloor - oceanic crust - sediments, crust, and mantle lithosphere - varies sufficiently systematically
#
# 10
# How is ocean crust formed?
# [CLS]
#
# How is ocean crust formed?
# [CLS]
#
# How is ocean crust formed?
# at mid - ocean ridges
#
# 10
# Is ocean crust being recycled?
# [CLS] is ocean crust being recycled? [SEP] oceanic crust. there are two types of crustal plates that make up the lithosphere. the continental plates contain the oldest rocks found on the planet. the oceanic crust is relatively young compared to the continental crust. the oceanic crust is constantly being created where plates are separating at divergent boundaries. the leading edge of the oceanic plate is constantly being melted and the rocks recycled in subduction zones. he oceanic crust is relatively young compared to the continental crust. the oceanic crust is constantly being created where plates are separating at divergent boundaries. the leading edge of the oceanic plate is constantly being melted and the rocks recycled in subduction zones.
#
# 10
# What is Darwin’s theory in a nutshell?
# [CLS]
#
# What is Darwin’s theory in a nutshell?
# [CLS] what is darwin ’ s theory in a nutshell? [SEP] howison, having thoroughly considered the various offerings from the history of his field ( see p. 394 of " limits ", for example ), arrived at what remains even today a unique offering. he developed his theory in the late 1880s, in consideration of another theory that was the rage of the times, darwin ’ s theory of evolution
#
# 10
# How was Darwin’s theory developed?
# [CLS] how was darwin ’ s theory developed? [SEP] beginning in the early 1990s, keleman developed his work with an emphasis on education rather than therapy. he has applied ideas from darwin ’ s theory of evolution
#
# 10
# How do sexual and asexual reproduction affect Darwin’s theory?
# [CLS]
#
# How do sexual and asexual reproduction affect Darwin’s theory?
# [CLS]
#
# How do sexual and asexual reproduction affect Darwin’s theory?
# by allowing populations to eliminate the deleterious mutations not only more rapidly, but also most effectively
#
# 10
# How can fossils be used to understand Darwin’s theory?
# [CLS]
#
# How can fossils be used to understand Darwin’s theory?
# [CLS]
#
# How can fossils be used to understand Darwin’s theory?
# [CLS]
#
# How can fossils be used to understand Darwin’s theory?
# [CLS]
#
# How can fossils be used to understand Darwin’s theory?
# [CLS]
#
# How can fossils be used to understand Darwin’s theory?
# [CLS]
#
# How can fossils be used to understand Darwin’s theory?
# [CLS]
#
# How can fossils be used to understand Darwin’s theory?
# [CLS]
#
# How can fossils be used to understand Darwin’s theory?
# [CLS]
#
# How can fossils be used to understand Darwin’s theory?
# [CLS]
#
# 10
# What is modern evidence for Darwin’s theory?
# [CLS]
#
# What is modern evidence for Darwin’s theory?
# [CLS]
#
# What is modern evidence for Darwin’s theory?
# [CLS]
#
# What is modern evidence for Darwin’s theory?
# [CLS]
#
# What is modern evidence for Darwin’s theory?
# [CLS]
#
# What is modern evidence for Darwin’s theory?
# [CLS]
#
# What is modern evidence for Darwin’s theory?
# [CLS]
#
# What is modern evidence for Darwin’s theory?
# [CLS]
#
# What is modern evidence for Darwin’s theory?
# [CLS]
#
# What is modern evidence for Darwin’s theory?
# [CLS]
#
# 10
# What is the impact of Darwin’s theory on modern biology?
# [CLS]
#
# What is the impact of Darwin’s theory on modern biology?
# [CLS]
#
# What is the impact of Darwin’s theory on modern biology?
# [CLS]
#
# What is the impact of Darwin’s theory on modern biology?
# [CLS]
#
# What is the impact of Darwin’s theory on modern biology?
# [CLS]
#
# What is the impact of Darwin’s theory on modern biology?
# [CLS]
#
# What is the impact of Darwin’s theory on modern biology?
# [CLS]
#
# What is the impact of Darwin’s theory on modern biology?
# [CLS]
#
# What is the impact of Darwin’s theory on modern biology?
# [CLS]
#
# What is the impact of Darwin’s theory on modern biology?
# [CLS]
#
# 10
# Compare and contrast microevolution and macroevolution.
# [CLS]
#
# Compare and contrast microevolution and macroevolution.
# [CLS]
#
# Compare and contrast microevolution and macroevolution.
# [CLS]
#
# Compare and contrast microevolution and macroevolution.
# [CLS]
#
# Compare and contrast microevolution and macroevolution.
# [CLS]
#
# Compare and contrast microevolution and macroevolution.
# [CLS]
#
# Compare and contrast microevolution and macroevolution.
# [CLS]
#
# Compare and contrast microevolution and macroevolution.
# [CLS]
#
# Compare and contrast microevolution and macroevolution.
# [CLS]
#
# Compare and contrast microevolution and macroevolution.
# [CLS]
#
# 10
# What is the relationship of Darwin's theory to speciation?
# [CLS]
#
# What is the relationship of Darwin's theory to speciation?
# [CLS]
#
# What is the relationship of Darwin's theory to speciation?
# [CLS]
#
# What is the relationship of Darwin's theory to speciation?
# [CLS]
#
# What is the relationship of Darwin's theory to speciation?
# [CLS]
#
# What is the relationship of Darwin's theory to speciation?
# [CLS]
#
# What is the relationship of Darwin's theory to speciation?
# [CLS]
#
# What is the relationship of Darwin's theory to speciation?
# [CLS]
#
# What is the relationship of Darwin's theory to speciation?
# [CLS]
#
# What is the relationship of Darwin's theory to speciation?
# [CLS]
#
# 10
# How can you tell if someone is suffering from depression?
# [CLS]
#
# How can you tell if someone is suffering from depression?
# [CLS]
#
# How can you tell if someone is suffering from depression?
#
#
# How can you tell if someone is suffering from depression?
# [CLS]
#
# How can you tell if someone is suffering from depression?
# [CLS]
#
# How can you tell if someone is suffering from depression?
# [CLS]
#
# How can you tell if someone is suffering from depression?
# [CLS]
#
# How can you tell if someone is suffering from depression?
# [CLS]
#
# How can you tell if someone is suffering from depression?
# [CLS]
#
# How can you tell if someone is suffering from depression?
# [CLS]
#
# 10
# What are common types of depression?
# [CLS]
#
# What are common types of depression?
# [CLS]
#
# What are common types of depression?
# [CLS]
#
# What are common types of depression?
# [CLS]
#
# What are common types of depression?
# [CLS]
#
# What are common types of depression?
# [CLS]
#
# What are common types of depression?
# [CLS]
#
# What are common types of depression?
# [CLS]
#
# What are common types of depression?
#
#
# What are common types of depression?
# [CLS]
#
# 10
# What causes depression?
# [CLS]
#
# What causes depression?
# [CLS]
#
# What causes depression?
# [CLS]
#
# What causes depression?
# [CLS]
#
# What causes depression?
# [CLS]
#
# What causes depression?
# [CLS]
#
# What causes depression?
# [CLS]
#
# What causes depression?
# [CLS]
#
# What causes depression?
# [CLS]
#
# What causes depression?
# [CLS]
#
# 10
# What is the role of brain chemicals in depression?
# [CLS]
#
# What is the role of brain chemicals in depression?
# [CLS] what is the role of brain chemicals in depression? [SEP] dopamine is an organic chemical of the catecholamine and phenethylamine families that plays several important roles in the human brain and body, as well as elsewhere in biology. its name derives from its chemical structure : it is an amine formed by removing a carboxyl group from a molecule of l - dopa. in the brain, dopamine functions as a neurotransmitter aa chemical released by nerve cells to send signals to other nerve cells
#
# 10
# Does a lack of sunlight cause depression?
# [CLS]
#
# Does a lack of sunlight cause depression?
# [CLS]
#
# Does a lack of sunlight cause depression?
# vitamin d deficiency
#
# 10
# How can you treat SAD?
# [CLS]
#
# How can you treat SAD?
# [CLS]
#
# How can you treat SAD?
# [CLS]
#
# How can you treat SAD?
# [CLS]
#
# How can you treat SAD?
# [CLS]
#
# How can you treat SAD?
# [CLS]
#
# How can you treat SAD?
# [CLS]
#
# How can you treat SAD?
# [CLS]
#
# How can you treat SAD?
# [CLS]
#
# How can you treat SAD?
# [CLS]
#
# 10
# What is the role of melatonin in SAD?
# [CLS]
#
# What is the role of melatonin in SAD?
# [CLS]
#
# What is the role of melatonin in SAD?
# [CLS]
#
# What is the role of melatonin in SAD?
#
#
# What is the role of melatonin in SAD?
# [CLS]
#
# What is the role of melatonin in SAD?
# [CLS]
#
# What is the role of melatonin in SAD?
# [CLS]
#
# What is the role of melatonin in SAD?
# [CLS]
#
# What is the role of melatonin in SAD?
# [CLS]
#
# What is the role of melatonin in SAD?
# [CLS]
#
# 10
# How are anxiety and depression related?
# [CLS]
#
# How are anxiety and depression related?
# [CLS]
#
# How are anxiety and depression related?
# [CLS]
#
# How are anxiety and depression related?
# [CLS]
#
# How are anxiety and depression related?
# [CLS]
#
# How are anxiety and depression related?
# [CLS]
#
# How are anxiety and depression related?
# [CLS]
#
# How are anxiety and depression related?
# [CLS]
#
# How are anxiety and depression related?
# [CLS]
#
# How are anxiety and depression related?
# [CLS]
#
# 10
# What treatments exist for depression?
# [CLS]
#
# What treatments exist for depression?
# [CLS]
#
# What treatments exist for depression?
# [CLS]
#
# What treatments exist for depression?
# [CLS]
#
# What treatments exist for depression?
# [CLS]
#
# What treatments exist for depression?
# [CLS]
#
# What treatments exist for depression?
# [CLS]
#
# What treatments exist for depression?
# [CLS]
#
# What treatments exist for depression?
# [CLS]
#
# What treatments exist for depression?
# [CLS]
#
# 10
# What is CBT and how does it work as a treatment for depression?
# cognitive behavioural therapy
#
# 10
# What is a real-time database?
# [CLS]
#
# What is a real-time database?
# [CLS]
#
# What is a real-time database?
# [CLS]
#
# What is a real-time database?
# [CLS]
#
# What is a real-time database?
# [CLS]
#
# What is a real-time database?
# [CLS]
#
# What is a real-time database?
# [CLS]
#
# What is a real-time database?
# [CLS]
#
# What is a real-time database?
# [CLS]
#
# What is a real-time database?
# [CLS]
#
# 10
# How does a real-time database differ from traditional databases?
# [CLS] how does a real - time database differ from traditional databases? [SEP] relational databases are powerful because they require few assumptions about how data is related or how it will be extracted from the database. as a result, the same database can be viewed in many different ways. an important feature of relational systems is that a single database can be spread across several tables. this differs from flat - file databases, in which each database is self - contained in a single table
#
# 10
# What are the advantages of real-time processing in real-time databases?
# [CLS]
#
# What are the advantages of real-time processing in real-time databases?
# [CLS]
#
# What are the advantages of real-time processing in real-time databases?
# [CLS]
#
# What are the advantages of real-time processing in real-time databases?
# [CLS]
#
# What are the advantages of real-time processing in real-time databases?
#
#
# What are the advantages of real-time processing in real-time databases?
#
#
# What are the advantages of real-time processing in real-time databases?
# [CLS]
#
# What are the advantages of real-time processing in real-time databases?
# [CLS]
#
# What are the advantages of real-time processing in real-time databases?
# [CLS]
#
# What are the advantages of real-time processing in real-time databases?
# [CLS]
#
# 10
# What are examples of important real-time databases?
# [CLS]
#
# What are examples of important real-time databases?
# [CLS]
#
# What are examples of important real-time databases?
# [CLS]
#
# What are examples of important real-time databases?
# [CLS]
#
# What are examples of important real-time databases?
# [CLS]
#
# What are examples of important real-time databases?
# [CLS]
#
# What are examples of important real-time databases?
# [CLS]
#
# What are examples of important real-time databases?
# [CLS]
#
# What are examples of important real-time databases?
# [CLS] what are examples of important real - time databases? [SEP] it is important therefore to understand exactly what service you require. it is also important to understand what is being calibrated and how the calibration is being performed. as an example, consider a digital thermometer that uses an external temperature probe
#
# 10
# What are important applications of real-time databases?
# [CLS]
#
# What are important applications of real-time databases?
# [CLS]
#
# What are important applications of real-time databases?
# [CLS]
#
# What are important applications of real-time databases?
# [CLS]
#
# What are important applications of real-time databases?
# [CLS]
#
# What are important applications of real-time databases?
# voice and real - time video
#
# 10
# What are important cloud options for real-time databases?
# [CLS]
#
# What are important cloud options for real-time databases?
# [CLS]
#
# What are important cloud options for real-time databases?
# [CLS]
#
# What are important cloud options for real-time databases?
# [CLS]
#
# What are important cloud options for real-time databases?
# [CLS]
#
# What are important cloud options for real-time databases?
# [CLS]
#
# What are important cloud options for real-time databases?
# [CLS]
#
# What are important cloud options for real-time databases?
# [CLS]
#
# What are important cloud options for real-time databases?
# [CLS]
#
# What are important cloud options for real-time databases?
# [CLS]
#
# 10
# Tell me about the Firebase DB.
# [CLS]
#
# Tell me about the Firebase DB.
# [CLS]
#
# Tell me about the Firebase DB.
# [CLS]
#
# Tell me about the Firebase DB.
# [CLS]
#
# Tell me about the Firebase DB.
# firebase analytics
#
# 10
# How is Firebase DB used in mobile apps?
# [CLS]
#
# How is Firebase DB used in mobile apps?
# [CLS] how is firebase db used in mobile apps? [SEP] firebase is a mobile and web application platform with tools and infrastructure designed to help developers build high - quality apps
#
# 10
# Which weekend sports have the most injuries?
# [CLS]
#
# Which weekend sports have the most injuries?
# [CLS]
#
# Which weekend sports have the most injuries?
# [CLS]
#
# Which weekend sports have the most injuries?
# [CLS]
#
# Which weekend sports have the most injuries?
# [CLS]
#
# Which weekend sports have the most injuries?
# [CLS]
#
# Which weekend sports have the most injuries?
# [CLS]
#
# Which weekend sports have the most injuries?
# [CLS]
#
# Which weekend sports have the most injuries?
# [CLS]
#
# Which weekend sports have the most injuries?
# [CLS]
#
# 10
# What are the most common types of injuries?
# [CLS]
#
# What are the most common types of injuries?
# [CLS]
#
# What are the most common types of injuries?
# [CLS]
#
# What are the most common types of injuries?
# [CLS]
#
# What are the most common types of injuries?
# [CLS]
#
# What are the most common types of injuries?
# [CLS]
#
# What are the most common types of injuries?
# [CLS]
#
# What are the most common types of injuries?
# [CLS]
#
# What are the most common types of injuries?
# [CLS]
#
# What are the most common types of injuries?
# [CLS]
#
# 10
# What is the ACL?
# [CLS]
#
# What is the ACL?
# [CLS]
#
# What is the ACL?
# [CLS]
#
# What is the ACL?
# [CLS]
#
# What is the ACL?
# [CLS]
#
# What is the ACL?
# [CLS]
#
# What is the ACL?
# [CLS]
#
# What is the ACL?
# [CLS]
#
# What is the ACL?
# [CLS]
#
# What is the ACL?
# [CLS]
#
# 10
# What is an injury for the ACL?
# [CLS]
#
# What is an injury for the ACL?
# [CLS]
#
# What is an injury for the ACL?
# [CLS]
#
# What is an injury for the ACL?
# [CLS]
#
# What is an injury for the ACL?
# [CLS]
#
# What is an injury for the ACL?
# [CLS]
#
# What is an injury for the ACL?
# [CLS]
#
# What is an injury for the ACL?
# [CLS]
#
# What is an injury for the ACL?
# [CLS]
#
# What is an injury for the ACL?
# [CLS]
#
# 10
# Tell me about the RICE method.
# [CLS]
#
# Tell me about the RICE method.
# [CLS]
#
# Tell me about the RICE method.
# [CLS]
#
# Tell me about the RICE method.
# [CLS]
#
# Tell me about the RICE method.
# [CLS]
#
# Tell me about the RICE method.
# the rice method
#
# 10
# Is there disagreement about the RICE method?
# [CLS]
#
# Is there disagreement about the RICE method?
# there is some disagreement among spaniards
#
# 10
# What is arnica used for in sports injuries?
# shock and trauma from injury
#
# 10
# What are some ways to avoid sports injuries?
# [CLS]
#
# What are some ways to avoid sports injuries?
# [CLS]
#
# What are some ways to avoid sports injuries?
# [CLS]
#
# What are some ways to avoid sports injuries?
# [CLS]
#
# What are some ways to avoid sports injuries?
# [CLS] what are some ways to avoid sports injuries? [SEP] however, in several ways, american soccer leagues have become more similar to leagues in the rest of the world in recent years. mls and usl now allow games to end in ties, which were initially avoided via a penalty shootout
#
# 10
# Tell me about the benefits of yoga.
# [CLS]
#
# Tell me about the benefits of yoga.
# [CLS]
#
# Tell me about the benefits of yoga.
# [CLS]
#
# Tell me about the benefits of yoga.
# [CLS]
#
# Tell me about the benefits of yoga.
# there is a long list benefits you always hear about in regards to the good it does for the mind and soul.
#
# 10
# Does yoga help in reducing stress?
# [CLS]
#
# Does yoga help in reducing stress?
# [CLS]
#
# Does yoga help in reducing stress?
# [CLS]
#
# Does yoga help in reducing stress?
# [CLS]
#
# Does yoga help in reducing stress?
# [CLS]
#
# Does yoga help in reducing stress?
# [CLS]
#
# Does yoga help in reducing stress?
# [CLS]
#
# Does yoga help in reducing stress?
#
#
# Does yoga help in reducing stress?
# [CLS]
#
# Does yoga help in reducing stress?
#
#
# 10
# What are some of the main types of yoga?
# [CLS]
#
# What are some of the main types of yoga?
# [CLS]
#
# What are some of the main types of yoga?
# [CLS]
#
# What are some of the main types of yoga?
# [CLS]
#
# What are some of the main types of yoga?
# [CLS]
#
# What are some of the main types of yoga?
# [CLS]
#
# What are some of the main types of yoga?
# [CLS]
#
# What are some of the main types of yoga?
# [CLS]
#
# What are some of the main types of yoga?
# [CLS]
#
# What are some of the main types of yoga?
# [CLS]
#
# 10
# What type of yoga is best for losing weight?
# [CLS]
#
# What type of yoga is best for losing weight?
# [CLS]
#
# What type of yoga is best for losing weight?
# [CLS]
#
# What type of yoga is best for losing weight?
# [CLS]
#
# What type of yoga is best for losing weight?
# ikram yoga benefits are just what you need when trying to lose weight right. bikram yoga
#
# 10
# What are common poses in Bikram yoga?
# [CLS]
#
# What are common poses in Bikram yoga?
# [CLS]
#
# What are common poses in Bikram yoga?
# [CLS]
#
# What are common poses in Bikram yoga?
# [CLS]
#
# What are common poses in Bikram yoga?
# awkward pose
#
# 10
# Why is mindful breathing important in yoga?
# [CLS]
#
# Why is mindful breathing important in yoga?
# [CLS]
#
# Why is mindful breathing important in yoga?
# [CLS]
#
# Why is mindful breathing important in yoga?
# to gain insight into the true nature of reality
#
# 10
# Does mindful breathing help relieve asthma?
# [CLS]
#
# Does mindful breathing help relieve asthma?
# [CLS]
#
# Does mindful breathing help relieve asthma?
# help relieve some form of their suffering.
#
# 10
# Who are The Avengers?
# [CLS]
#
# Who are The Avengers?
# [CLS]
#
# Who are The Avengers?
# [CLS]
#
# Who are The Avengers?
#
#
# Who are The Avengers?
# [CLS]
#
# Who are The Avengers?
# [CLS]
#
# Who are The Avengers?
# [CLS]
#
# Who are The Avengers?
# [CLS]
#
# Who are The Avengers?
# [CLS]
#
# Who are The Avengers?
# [CLS]
#
# 10
# Tell me about The Avengers' first appearance.
# [CLS]
#
# Tell me about The Avengers' first appearance.
# [CLS]
#
# Tell me about The Avengers' first appearance.
# [CLS]
#
# Tell me about The Avengers' first appearance.
# [CLS]
#
# Tell me about The Avengers' first appearance.
# [CLS]
#
# Tell me about The Avengers' first appearance.
# [CLS]
#
# Tell me about The Avengers' first appearance.
# [CLS]
#
# Tell me about The Avengers' first appearance.
# [CLS]
#
# Tell me about The Avengers' first appearance.
# [CLS]
#
# Tell me about The Avengers' first appearance.
# [CLS]
#
# 10
# Who is the most powerful of The Avengers and why?
#
#
# Who is the most powerful of The Avengers and why?
# [CLS]
#
# Who is the most powerful of The Avengers and why?
# thunder god thor
#
# 10
# What is the relationship of Spider-Man to The Avengers?
# [CLS]
#
# What is the relationship of Spider-Man to The Avengers?
# [CLS]
#
# What is the relationship of Spider-Man to The Avengers?
# [CLS]
#
# What is the relationship of Spider-Man to The Avengers?
# [CLS]
#
# What is the relationship of Spider-Man to The Avengers?
# [CLS]
#
# What is the relationship of Spider-Man to The Avengers?
# [CLS]
#
# What is the relationship of Spider-Man to The Avengers?
# [CLS]
#
# What is the relationship of Spider-Man to The Avengers?
# [CLS]
#
# What is the relationship of Spider-Man to The Avengers?
# [CLS]
#
# What is the relationship of Spider-Man to The Avengers?
# [CLS]
#
# 10
# Why is Batman not a member of The Avengers?
# [CLS]
#
# Why is Batman not a member of The Avengers?
# [CLS]
#
# Why is Batman not a member of The Avengers?
# [CLS]
#
# Why is Batman not a member of The Avengers?
# [CLS]
#
# Why is Batman not a member of The Avengers?
# [CLS] why is batman not a member of the avengers? [SEP] robin ( dick grayson ) is one of the main cast members in the animated adaptation of young justice. the character is voiced by actor jesse mccartney. along with aqualad, kid flash and superboy, robin is one of the founding members of young justice. however, when not on team missions, he still lives and performs his duties in gotham city. as the most experienced member of the team, he assumed that he would automatically be the leader, but this would prove to not be the case. when in combat with batman, their relationship is so defined that they don't need to communicate
#
# 10
# What is an important team in the DC universe?
# [CLS]
#
# What is an important team in the DC universe?
# [CLS]
#
# What is an important team in the DC universe?
# [CLS]
#
# What is an important team in the DC universe?
# [CLS]
#
# What is an important team in the DC universe?
# [CLS]
#
# What is an important team in the DC universe?
# [CLS]
#
# What is an important team in the DC universe?
# [CLS]
#
# What is an important team in the DC universe?
# [CLS]
#
# What is an important team in the DC universe?
# [CLS]
#
# What is an important team in the DC universe?
# [CLS]
#
# 10
# Tell me about the origins of the Justice League in the DC universe.
# [CLS]
#
# Tell me about the origins of the Justice League in the DC universe.
# [CLS]
#
# Tell me about the origins of the Justice League in the DC universe.
# [CLS]
#
# Tell me about the origins of the Justice League in the DC universe.
# [CLS]
#
# Tell me about the origins of the Justice League in the DC universe.
# [CLS]
#
# Tell me about the origins of the Justice League in the DC universe.
# [CLS]
#
# Tell me about the origins of the Justice League in the DC universe.
# [CLS]
#
# Tell me about the origins of the Justice League in the DC universe.
# [CLS]
#
# Tell me about the origins of the Justice League in the DC universe.
# [CLS]
#
# Tell me about the origins of the Justice League in the DC universe.
# [CLS]
#
# 10
# Who are the important members of the Justice League?
# [CLS]
#
# Who are the important members of the Justice League?
# [CLS]
#
# Who are the important members of the Justice League?
# [CLS]
#
# Who are the important members of the Justice League?
# [CLS]
#
# Who are the important members of the Justice League?
# [CLS]
#
# Who are the important members of the Justice League?
# [CLS]
#
# Who are the important members of the Justice League?
# [CLS]
#
# Who are the important members of the Justice League?
# [CLS]
#
# Who are the important members of the Justice League?
# [CLS]
#
# Who are the important members of the Justice League?
# [CLS]
#
# 10
# Did the Justice League or The Avengers come first?
# [CLS]
#
# Did the Justice League or The Avengers come first?
# [CLS]
#
# Did the Justice League or The Avengers come first?
# [CLS]
#
# Did the Justice League or The Avengers come first?
# [CLS] did the justice league or the avengers come first? [SEP] in jla / avengers, ray appears first as taking the place of wally west during the justice league's mission to the marvel universe when he realizes that there is no speed force in the other reality. the justice league
#
# 10
# What is the Surrealism movement in art?
# [CLS] what is the surrealism movement in art? [SEP] what makes the surrealist movement unique is their fascination with the unconscious mind
#
# 10
# What are characteristics of the Surrealism movement?
# [CLS]
#
# What are characteristics of the Surrealism movement?
# [CLS]
#
# What are characteristics of the Surrealism movement?
# [CLS]
#
# What are characteristics of the Surrealism movement?
# [CLS]
#
# What are characteristics of the Surrealism movement?
# [CLS]
#
# What are characteristics of the Surrealism movement?
# [CLS]
#
# What are characteristics of the Surrealism movement?
# [CLS]
#
# What are characteristics of the Surrealism movement?
# the use of modern technology to fuse surrealism's traditional access to the unconscious with pop art's ironic contradictions
#
# 10
# Tell me about the Surrealism movement's founding.
# [CLS]
#
# Tell me about the Surrealism movement's founding.
# [CLS]
#
# Tell me about the Surrealism movement's founding.
# [CLS]
#
# Tell me about the Surrealism movement's founding.
# [CLS]
#
# Tell me about the Surrealism movement's founding.
# [CLS]
#
# Tell me about the Surrealism movement's founding.
# [CLS]
#
# Tell me about the Surrealism movement's founding.
# [CLS]
#
# Tell me about the Surrealism movement's founding.
# penguins
#
# 10
# Tell me about the series of manifestos in the Surrealism movement.
# [CLS]
#
# Tell me about the series of manifestos in the Surrealism movement.
# [CLS]
#
# Tell me about the series of manifestos in the Surrealism movement.
# [CLS]
#
# Tell me about the series of manifestos in the Surrealism movement.
# [CLS]
#
# Tell me about the series of manifestos in the Surrealism movement.
# [CLS]
#
# Tell me about the series of manifestos in the Surrealism movement.
# [CLS]
#
# Tell me about the series of manifestos in the Surrealism movement.
# [CLS]
#
# Tell me about the series of manifestos in the Surrealism movement.
# [CLS]
#
# Tell me about the series of manifestos in the Surrealism movement.
# [CLS]
#
# Tell me about the series of manifestos in the Surrealism movement.
# [CLS]
#
# 10
# How is Surrealism movement different from Dada?
# instead of focusing on the future, afro - surrealism focuses more on the present day
#
# 10
# What is the importance of the Surrealism movement?
# [CLS]
#
# What is the importance of the Surrealism movement?
# [CLS] what is the importance of the surrealism movement? [SEP] surrealism in art, poetry, and literature uses numerous techniques and games to provide inspiration. many of these are said to free imagination by producing a creative process free of conscious control. the importance of the unconscious as a source of inspiration
#
# 10
# Who are the most famous artists in the Surrealism movement?
# [CLS]
#
# Who are the most famous artists in the Surrealism movement?
# salvador dali, rene magritte and alberto giacometti
#
# 10
# Why did Dali choose surrealism?
# [CLS]
#
# Why did Dali choose surrealism?
# [CLS]
#
# Why did Dali choose surrealism?
# [CLS]
#
# Why did Dali choose surrealism?
# [CLS]
#
# Why did Dali choose surrealism?
# [CLS]
#
# Why did Dali choose surrealism?
# [CLS]
#
# Why did Dali choose surrealism?
# [CLS]
#
# Why did Dali choose surrealism?
# [CLS]
#
# Why did Dali choose surrealism?
# [CLS]
#
# Why did Dali choose surrealism?
# [CLS]
#
# 10
# What are Dali's most iconic works?
# [CLS]
#
# What are Dali's most iconic works?
# [CLS]
#
# What are Dali's most iconic works?
# [CLS]
#
# What are Dali's most iconic works?
# [CLS]
#
# What are Dali's most iconic works?
# [CLS]
#
# What are Dali's most iconic works?
# [CLS]
#
# What are Dali's most iconic works?
# [CLS]
#
# What are Dali's most iconic works?
# [CLS]
#
# What are Dali's most iconic works?
# [CLS]
#
# What are Dali's most iconic works?
# [CLS]
#
# 10
# Is the Surrealism movement in art still used today?
# [CLS]
#
# Is the Surrealism movement in art still used today?
# [CLS]
#
# Is the Surrealism movement in art still used today?
# [CLS]
#
# Is the Surrealism movement in art still used today?
# [CLS]
#
# Is the Surrealism movement in art still used today?
# [CLS] is the surrealism movement in art still used today? [SEP] in the 1930s, art moved into a new phase with experiments in the theoretical and intellectual use of shapes and symbols while at the same time a symbolism emerged from the world of dreams. this was the basis for concrete art and surrealism which became the latest trend in the international avant - garde movement
#
# 10
# What has been the Surrealism movement's impact on other fields?
# [CLS]
#
# What has been the Surrealism movement's impact on other fields?
# [CLS]
#
# What has been the Surrealism movement's impact on other fields?
# widespread impact among neuroscientists but have also generated controversy
#
# 10
# What is blockchain?
# [CLS]
#
# What is blockchain?
# [CLS]
#
# What is blockchain?
# [CLS]
#
# What is blockchain?
# [CLS]
#
# What is blockchain?
# [CLS]
#
# What is blockchain?
# [CLS]
#
# What is blockchain?
# [CLS]
#
# What is blockchain?
# [CLS]
#
# What is blockchain?
# [CLS]
#
# What is blockchain?
# [CLS]
#
# 10
# What problem does blockchain solve?
# [CLS]
#
# What problem does blockchain solve?
# what
#
# 10
# How does blockchain work?
# [CLS]
#
# How does blockchain work?
# [CLS]
#
# How does blockchain work?
# [CLS]
#
# How does blockchain work?
# [CLS]
#
# How does blockchain work?
# [CLS]
#
# How does blockchain work?
# [CLS]
#
# How does blockchain work?
# [CLS]
#
# How does blockchain work?
# [CLS]
#
# How does blockchain work?
# [CLS]
#
# How does blockchain work?
# [CLS]
#
# 10
# What are the types of blockchain networks?
# [CLS]
#
# What are the types of blockchain networks?
# [CLS]
#
# What are the types of blockchain networks?
# [CLS] what are the types of blockchain networks? [SEP] different types of blockchain available in market these are public blockchain, private blockchain, and consortium blockchain
#
# 10
# Tell me about blockchain's invention.
# [CLS]
#
# Tell me about blockchain's invention.
# [CLS]
#
# Tell me about blockchain's invention.
# blockchain's invention
#
# 10
# How is blockchain related to cryptocurrencies?
# quadrupled
#
# 10
# How is Bitcoin generated?
# [CLS]
#
# How is Bitcoin generated?
# [CLS]
#
# How is Bitcoin generated?
# [CLS]
#
# How is Bitcoin generated?
# [CLS]
#
# How is Bitcoin generated?
# [CLS]
#
# How is Bitcoin generated?
# cryptocurrencies what is bitcoin, how to use bitcoin
#
# 10
# How secure is blockchain?
# [CLS]
#
# How secure is blockchain?
# [CLS]
#
# How secure is blockchain?
# [CLS]
#
# How secure is blockchain?
# [CLS]
#
# How secure is blockchain?
# [CLS]
#
# How secure is blockchain?
# [CLS]
#
# How secure is blockchain?
# [CLS]
#
# How secure is blockchain?
# [CLS]
#
# How secure is blockchain?
# [CLS]
#
# How secure is blockchain?
# [CLS]
#
# 10
# What are blockchain's other uses in business?
# [CLS]
#
# What are blockchain's other uses in business?
# [CLS]
#
# What are blockchain's other uses in business?
# [CLS]
#
# What are blockchain's other uses in business?
# [CLS]
#
# What are blockchain's other uses in business?
# [CLS]
#
# What are blockchain's other uses in business?
# [CLS]
#
# What are blockchain's other uses in business?
# [CLS]
#
# What are blockchain's other uses in business?
# [CLS]
#
# What are blockchain's other uses in business?
# [CLS]
#
# What are blockchain's other uses in business?
# [CLS]
#
# 10
# What are the implications of blockchain for society?
# politically powerful actors may make decisions that favor some groups at the expense of others
#
# 10
# What are the types of pork ribs?
# [CLS]
#
# What are the types of pork ribs?
# [CLS]
#
# What are the types of pork ribs?
# [CLS]
#
# What are the types of pork ribs?
# [CLS]
#
# What are the types of pork ribs?
# [CLS]
#
# What are the types of pork ribs?
# [CLS] what are the types of pork ribs? [SEP] that would depend on how you want your sausage to cook up, how lean your game meat is, what type of game meat and type of pork you are using. here are some guidelines for venison or elk : using a ratio of 50 % game meat with 50 % pork butts
#
# 10
# What are baby back pork ribs?
# [CLS] what are baby back pork ribs? [SEP] pork ribs baby back - baked no sauce
#
# 10
# What are the differences between baby back ribs and spareribs?
# [CLS] what are the differences between baby back ribs and spareribs? [SEP] 1. decide what kind of ribs you want to grill. the 2 most popular types are baby back ribs and spare ribs, but there are significant differences between the 2 cuts. 1 baby back ribs come from the top of the rib cage. 2 they range in length from 3 inches ( 7. 6 cm ) to 6 inches ( 15. 2 cm )
#
# 10
# What are ways to cook pork ribs?
# [CLS]
#
# What are ways to cook pork ribs?
# [CLS]
#
# What are ways to cook pork ribs?
# [CLS]
#
# What are ways to cook pork ribs?
# [CLS]
#
# What are ways to cook pork ribs?
# [CLS]
#
# What are ways to cook pork ribs?
# [CLS]
#
# What are ways to cook pork ribs?
# [CLS]
#
# What are ways to cook pork ribs?
# [CLS]
#
# What are ways to cook pork ribs?
# [CLS]
#
# What are ways to cook pork ribs?
# [CLS]
#
# 10
# How do you cook pork ribs on the bbq?
# [CLS]
#
# How do you cook pork ribs on the bbq?
# [CLS]
#
# How do you cook pork ribs on the bbq?
# [CLS]
#
# How do you cook pork ribs on the bbq?
# [CLS]
#
# How do you cook pork ribs on the bbq?
# [CLS]
#
# How do you cook pork ribs on the bbq?
# [CLS]
#
# How do you cook pork ribs on the bbq?
# how to dry roast pork ribs in an oven you can cook pork ribs in one of two ways : moist or dry
#
# 10
# Describe the 321 method of cooking pork ribs
# [CLS]
#
# Describe the 321 method of cooking pork ribs
# [CLS]
#
# Describe the 321 method of cooking pork ribs
# [CLS]
#
# Describe the 321 method of cooking pork ribs
# [CLS]
#
# Describe the 321 method of cooking pork ribs
# [CLS]
#
# Describe the 321 method of cooking pork ribs
# [CLS]
#
# Describe the 321 method of cooking pork ribs
# [CLS]
#
# Describe the 321 method of cooking pork ribs
# [CLS]
#
# Describe the 321 method of cooking pork ribs
# [CLS]
#
# Describe the 321 method of cooking pork ribs
# [CLS]
#
# 10
# How long do pork ribs take to smoke?
# [CLS]
#
# How long do pork ribs take to smoke?
# [CLS]
#
# How long do pork ribs take to smoke?
# [CLS]
#
# How long do pork ribs take to smoke?
# [CLS]
#
# How long do pork ribs take to smoke?
# [CLS]
#
# How long do pork ribs take to smoke?
# [CLS]
#
# How long do pork ribs take to smoke?
# [CLS]
#
# How long do pork ribs take to smoke?
# 5
#
# 10
# How do you know when pork ribs are done smoking?
# [CLS]
#
# How do you know when pork ribs are done smoking?
# [CLS]
#
# How do you know when pork ribs are done smoking?
# [CLS]
#
# How do you know when pork ribs are done smoking?
# [CLS]
#
# How do you know when pork ribs are done smoking?
# [CLS]
#
# How do you know when pork ribs are done smoking?
# [CLS]
#
# How do you know when pork ribs are done smoking?
# [CLS]
#
# How do you know when pork ribs are done smoking?
# [CLS]
#
# How do you know when pork ribs are done smoking?
# [CLS]
#
# How do you know when pork ribs are done smoking?
# [CLS]
#
# 10
# What is in a typical pork rib bbq rub?
# [CLS] what is in a typical pork rib bbq rub? [SEP] pulled chicken 6. 99 grilled chicken 7. 99 sonnyas steakburger * 7. 99 pulled or sliced pork 11. 59 baby back ribs 15. 59 st. louis ribs sweet & smokey or house dry - rubbed. 12. 99 half chicken 10. 99 all - white meat, add. 99. beef brisket lb sliced ( lean ) or chopped ( marbled ). 13. 59 pulled chicken 11. 99 smoked turkey 10. 99 sonnyas sampler pulled pork, sliced brisket, 1 / 4 bbq chicken and sweet & smokey ribs. 15. 59 ribs & chicken 12. 99 chicken & pork 11. 99 ribs & smoked wings 13. 59 pork 3 waysa® pulled pork, sliced pork and sweet & smokey ribs. 13. 99 family feast pulled pork, sliced brisket
#
# 10
# What’s the best style of sauce for pork ribs?
# [CLS]
#
# What’s the best style of sauce for pork ribs?
# chatelaineas memphis
#
# 10
# What’s in Kansas City style BBQ sauce?
# [CLS]
#
# What’s in Kansas City style BBQ sauce?
# ribs, sausage and pulled pork
#
# 10
# What is nominal GDP?
# [CLS]
#
# What is nominal GDP?
# [CLS]
#
# What is nominal GDP?
# [CLS]
#
# What is nominal GDP?
# [CLS]
#
# What is nominal GDP?
# [CLS]
#
# What is nominal GDP?
# [CLS]
#
# What is nominal GDP?
# [CLS]
#
# What is nominal GDP?
# [CLS]
#
# What is nominal GDP?
# [CLS]
#
# What is nominal GDP?
# [CLS]
#
# 10
# Why is nominal GDP not a good measure?
# [CLS] why is nominal gdp not a good measure? [SEP] comparisons of national wealth are frequently made on the basis of nominal gdp and savings ( not just income ), which don't reflect differences in the cost of living in different countries ( see list of countries by gdp ( nominal ) per capita ) ; hence, using a ppp basis is arguably more useful when comparing generalized differences in living standards between nations because ppp takes into account the relative cost of living and the inflation rates of the countries, rather than using only exchange rates, which may distort the real differences in income. this is why gdp ( ppp ) per capita is often considered one of the indicators of a country's standard of living, although this can be problematic because gdp per capita is not a measure of personal income
#
# 10
# What is the between nominal and real GDP?
# [CLS]
#
# What is the between nominal and real GDP?
# [CLS]
#
# What is the between nominal and real GDP?
# [CLS]
#
# What is the between nominal and real GDP?
# [CLS]
#
# What is the between nominal and real GDP?
# the inflation rate
#
# 10
# How is nominal GDP related to gross national income?
# [CLS]
#
# How is nominal GDP related to gross national income?
# reflects prices which were current at the time
#
# 10
# What is the meaning of GNI?
# [CLS]
#
# What is the meaning of GNI?
# [CLS]
#
# What is the meaning of GNI?
# [CLS]
#
# What is the meaning of GNI?
# [CLS]
#
# What is the meaning of GNI?
# [CLS]
#
# What is the meaning of GNI?
# [CLS]
#
# What is the meaning of GNI?
# [CLS]
#
# What is the meaning of GNI?
# [CLS]
#
# What is the meaning of GNI?
# [CLS]
#
# What is the meaning of GNI?
# [CLS]
#
# 10
# How is inflation affected by high GDP growth?
# [CLS]
#
# How is inflation affected by high GDP growth?
# [CLS]
#
# How is inflation affected by high GDP growth?
# [CLS] how is inflation affected by high gdp growth? [SEP] real gross domestic product ( gdp ) represents the method by which economists assess growth in a country's economy. this particular measure considers inflation in the final results. real gdp growth can be affected by various factors
#
# 10
# What is the relationship between inflation and unemployment?
# [CLS]
#
# What is the relationship between inflation and unemployment?
# [CLS]
#
# What is the relationship between inflation and unemployment?
# [CLS]
#
# What is the relationship between inflation and unemployment?
# trade - off between inflation and unemployment or real economic performance
#
# 10
# What is frictional unemployment and why is it important?
# [CLS]
#
# What is frictional unemployment and why is it important?
# full employment is not
#
# 10
# Is frictional unemployment bad for the economy?
# [CLS]
#
# Is frictional unemployment bad for the economy?
# frictional unemployment is always present in an economy
#
# 10
# How can the government reduce the level of frictional unemployment?
#
#
# How can the government reduce the level of frictional unemployment?
# [CLS]
#
# How can the government reduce the level of frictional unemployment?
# [CLS]
#
# How can the government reduce the level of frictional unemployment?
# [CLS]
#
# How can the government reduce the level of frictional unemployment?
# seek ways to reduce unnecessary frictional unemployment.
#
# 10
# Tell me about lavender plants.
# [CLS]
#
# Tell me about lavender plants.
# [CLS]
#
# Tell me about lavender plants.
# [CLS]
#
# Tell me about lavender plants.
# [CLS]
#
# Tell me about lavender plants.
# [CLS]
#
# Tell me about lavender plants.
# [CLS]
#
# Tell me about lavender plants.
# [CLS]
#
# Tell me about lavender plants.
# [CLS]
#
# Tell me about lavender plants.
# [CLS]
#
# Tell me about lavender plants.
# [CLS]
#
# 10
# What are the different types of lavender plants?
# [CLS] what are the different types of lavender plants? [SEP] spike lavender. spike, or portuguese, lavender ( l. latifolia ) is native to the mountains of spain, france and portugal. quite different from other types, spike lavender plants are 3 feet tall and 4 feet wide
#
# 10
# What places are famous for lavender plants?
# [CLS]
#
# What places are famous for lavender plants?
# [CLS]
#
# What places are famous for lavender plants?
# [CLS]
#
# What places are famous for lavender plants?
# [CLS]
#
# What places are famous for lavender plants?
# [CLS] what places are famous for lavender plants? [SEP] tours in provence. discover the best and famous tour of provence with experts and local guides which includes sightseeing, day tours, famous vineyards
#
# 10
# Are lavender plants safe to eat?
# [CLS]
#
# Are lavender plants safe to eat?
# [CLS]
#
# Are lavender plants safe to eat?
# safe to plant either inside or outside your home
#
# 10
# What variety of lavender is best for cooking?
# [CLS]
#
# What variety of lavender is best for cooking?
# [CLS]
#
# What variety of lavender is best for cooking?
# [CLS]
#
# What variety of lavender is best for cooking?
# [CLS]
#
# What variety of lavender is best for cooking?
# [CLS]
#
# What variety of lavender is best for cooking?
# [CLS]
#
# What variety of lavender is best for cooking?
# [CLS]
#
# What variety of lavender is best for cooking?
# [CLS]
#
# What variety of lavender is best for cooking?
# [CLS]
#
# What variety of lavender is best for cooking?
# [CLS]
#
# 10
# How is lavender used in cooking?
# [CLS]
#
# How is lavender used in cooking?
# [CLS]
#
# How is lavender used in cooking?
# [CLS]
#
# How is lavender used in cooking?
# [CLS] how is lavender used in cooking? [SEP] 1 you can use either fresh or dry lavender buds for this project. 2 i didnat remove my lavender buds from the stalk. 3 the stalks have some of the same fragrant oils as the flowers / buds but not as much. 4 pour the lavender into the bowl or mortar
#
# 10
# What foods is lavender good for cooking with?
# vanilla
#
# 10
# What are the health benefits of lavender oil?
# [CLS]
#
# What are the health benefits of lavender oil?
# [CLS]
#
# What are the health benefits of lavender oil?
# [CLS]
#
# What are the health benefits of lavender oil?
# its ability to eliminate nervous tension, relieve pain, disinfect the scalp and skin, enhance blood circulation, and treat respiratory problems
#
# 10
# Are there any side effects of lavender oil?
# they did not determine if there are any side effects of having catnip extract on skin a does it irritate the skin
#
# 10
# Why is blood red?
# [CLS]
#
# Why is blood red?
# [CLS]
#
# Why is blood red?
# [CLS]
#
# Why is blood red?
# [CLS]
#
# Why is blood red?
# [CLS]
#
# Why is blood red?
# [CLS]
#
# Why is blood red?
# [CLS]
#
# Why is blood red?
# [CLS]
#
# Why is blood red?
# [CLS]
#
# Why is blood red?
# [CLS]
#
# 10
# What are red blood cells?
# [CLS]
#
# What are red blood cells?
# [CLS]
#
# What are red blood cells?
# [CLS]
#
# What are red blood cells?
# [CLS]
#
# What are red blood cells?
# [CLS]
#
# What are red blood cells?
# [CLS]
#
# What are red blood cells?
# [CLS]
#
# What are red blood cells?
# [CLS]
#
# What are red blood cells?
# erythorocytes
#
# 10
# How are red blood cells created?
# [CLS]
#
# How are red blood cells created?
# [CLS]
#
# How are red blood cells created?
# [CLS]
#
# How are red blood cells created?
# [CLS]
#
# How are red blood cells created?
# [CLS]
#
# How are red blood cells created?
# [CLS]
#
# How are red blood cells created?
# [CLS]
#
# How are red blood cells created?
# [CLS]
#
# How are red blood cells created?
# [CLS]
#
# How are red blood cells created?
# [CLS]
#
# 10
# How is oxygen transported in blood?
# [CLS]
#
# How is oxygen transported in blood?
# hemoglobin
#
# 10
# What is anemia?
# [CLS]
#
# What is anemia?
# [CLS]
#
# What is anemia?
# [CLS]
#
# What is anemia?
# [CLS]
#
# What is anemia?
# [CLS]
#
# What is anemia?
# [CLS]
#
# What is anemia?
# [CLS]
#
# What is anemia?
# 6
#
# 10
# What are the symptoms of anemia?
# [CLS]
#
# What are the symptoms of anemia?
# 6
#
# 10
# Can anemia go away?
# [CLS]
#
# Can anemia go away?
# [CLS]
#
# Can anemia go away?
# [CLS]
#
# Can anemia go away?
# [CLS]
#
# Can anemia go away?
# [CLS]
#
# Can anemia go away?
# [CLS]
#
# Can anemia go away?
# [CLS]
#
# Can anemia go away?
# [CLS]
#
# Can anemia go away?
# [CLS]
#
# Can anemia go away?
# [CLS]
#
# 10
# What are anemia's possible causes?
# [CLS]
#
# What are anemia's possible causes?
# [CLS]
#
# What are anemia's possible causes?
# [CLS]
#
# What are anemia's possible causes?
# [CLS]
#
# What are anemia's possible causes?
# [CLS]
#
# What are anemia's possible causes?
# [CLS]
#
# What are anemia's possible causes?
# [CLS]
#
# What are anemia's possible causes?
# [CLS]
#
# What are anemia's possible causes?
#
#
# What are anemia's possible causes?
# [CLS]
#
# 10
# How is anemia treated?
# [CLS]
#
# How is anemia treated?
# [CLS]
#
# How is anemia treated?
# [CLS]
#
# How is anemia treated?
# [CLS]
#
# How is anemia treated?
# [CLS]
#
# How is anemia treated?
# [CLS]
#
# How is anemia treated?
# [CLS]
#
# How is anemia treated?
# [CLS]
#
# How is anemia treated?
# [CLS]
#
# How is anemia treated?
# [CLS]
#
# 10
# What foods contain high levels of iron?
# [CLS]
#
# What foods contain high levels of iron?
# [CLS]
#
# What foods contain high levels of iron?
# [CLS]
#
# What foods contain high levels of iron?
# raw eggs, garlic, onions and fresh unprocessed meats
#
# 10
# What improves iron absorption?
# vitamin c
#
# 10
# What is cuisine is Emilia-Romagna famous for?
# [CLS]
#
# What is cuisine is Emilia-Romagna famous for?
# [CLS]
#
# What is cuisine is Emilia-Romagna famous for?
# [CLS]
#
# What is cuisine is Emilia-Romagna famous for?
# [CLS]
#
# What is cuisine is Emilia-Romagna famous for?
# [CLS]
#
# What is cuisine is Emilia-Romagna famous for?
# [CLS]
#
# What is cuisine is Emilia-Romagna famous for?
# [CLS]
#
# What is cuisine is Emilia-Romagna famous for?
# [CLS]
#
# What is cuisine is Emilia-Romagna famous for?
# [CLS]
#
# What is cuisine is Emilia-Romagna famous for?
# [CLS]
#
# 10
# Tell me about cooking schools and classes in Emilia-Romagna.
# [CLS]
#
# Tell me about cooking schools and classes in Emilia-Romagna.
# [CLS]
#
# Tell me about cooking schools and classes in Emilia-Romagna.
# [CLS]
#
# Tell me about cooking schools and classes in Emilia-Romagna.
# [CLS]
#
# Tell me about cooking schools and classes in Emilia-Romagna.
# cooking schools
#
# 10
# What are famous foods from Emilia-Romagna?
# [CLS]
#
# What are famous foods from Emilia-Romagna?
# [CLS]
#
# What are famous foods from Emilia-Romagna?
# [CLS]
#
# What are famous foods from Emilia-Romagna?
# [CLS]
#
# What are famous foods from Emilia-Romagna?
# [CLS]
#
# What are famous foods from Emilia-Romagna?
# [CLS]
#
# What are famous foods from Emilia-Romagna?
# [CLS]
#
# What are famous foods from Emilia-Romagna?
# [CLS]
#
# What are famous foods from Emilia-Romagna?
# [CLS]
#
# What are famous foods from Emilia-Romagna?
# [CLS]
#
# 10
# Describe the traditional process for making balsamic vinegar.
# [CLS]
#
# Describe the traditional process for making balsamic vinegar.
# [CLS]
#
# Describe the traditional process for making balsamic vinegar.
# [CLS]
#
# ...
# [CLS]
#
# What are some important modern uses of allegory?
# [CLS]
#
# What are some important modern uses of allegory?
# [CLS]
#
# What are some important modern uses of allegory?
# [CLS] what are some important modern uses of allegory? [SEP] modern science can illuminate how and why people respond in certain ways to food plating and presentation. according to a sociological study people react differently to various aesthetic principles such as color, composition ( including number of components, placement of components, and use of negative space ), design, and the organization of a plate. they found that participants responded best to plates with four different colors, three different components, some empty space, and with a disorganized and casual design. this research is particularly important because understanding how food presentation affects how people eat can be used used in the study of health and nutrition. for instance, another study showed that participants who ate off of uncleaned tables ( i. e all uneaten food was left on the table ) ate less than those that had their tabled periodically cleaned. this is presumably because those that could see the leftovers of what they had eaten were less likely to take more food. this could be useful, for instance, in combatting the obesity endemic. another example of science in food aesthetics is the development of molecular food in spain, which emphasizes the essence of food using scientific elements. molecular science can break down the roles of carbohydrates and protein in order to isolate what creates particular tastes. for instance, modern science makes it possible to freeze ice cream using liquid nitrogen and create wine using sugars, creating efficient and visually interesting new dishes
#
# 10
# What are the different types of foreshadowing?
# [CLS]
#
# What are the different types of foreshadowing?
# [CLS]
#
# What are the different types of foreshadowing?
# [CLS]
#
# What are the different types of foreshadowing?
# [CLS]
#
# What are the different types of foreshadowing?
# [CLS]
#
# What are the different types of foreshadowing?
# [CLS]
#
# What are the different types of foreshadowing?
# [CLS]
#
# What are the different types of foreshadowing?
# [CLS]
#
# What are the different types of foreshadowing?
# [CLS]
#
# What are the different types of foreshadowing?
# [CLS]
#
# 10
# What is an example of foreshadowing?
# [CLS]
#
# What is an example of foreshadowing?
# [CLS]
#
# What is an example of foreshadowing?
# [CLS]
#
# What is an example of foreshadowing?
# [CLS]
#
# What is an example of foreshadowing?
# [CLS]
#
# What is an example of foreshadowing?
# [CLS]
#
# What is an example of foreshadowing?
# [CLS]
#
# What is an example of foreshadowing?
# [CLS]
#
# What is an example of foreshadowing?
# [CLS]
#
# What is an example of foreshadowing?
# [CLS]
#
# 10
# What's the difference between soup and stew?
# [CLS]
#
# What's the difference between soup and stew?
# the size of chunks of food
#
# 10
# Is chilli a stew?
# [CLS]
#
# Is chilli a stew?
# [CLS]
#
# Is chilli a stew?
# [CLS]
#
# Is chilli a stew?
# [CLS]
#
# Is chilli a stew?
# [CLS]
#
# Is chilli a stew?
# [CLS]
#
# Is chilli a stew?
# [CLS]
#
# Is chilli a stew?
# [CLS]
#
# Is chilli a stew?
# [CLS]
#
# Is chilli a stew?
# [CLS]
#
# 10
# Is goulash a stew?
# [CLS]
#
# Is goulash a stew?
# a · goulash is a type of stew
#
# 10
# What are popular stews in France?
# [CLS]
#
# What are popular stews in France?
#
#
# What are popular stews in France?
# [CLS]
#
# What are popular stews in France?
# bowara, pumpkin leaves
#
# 10
# How is cassoulet made?
# [CLS]
#
# How is cassoulet made?
# [CLS]
#
# How is cassoulet made?
# [CLS]
#
# How is cassoulet made?
# [CLS]
#
# How is cassoulet made?
# takes some time and effort
#
# 10
# Tell me about feijoada and its significance.
# [CLS]
#
# Tell me about feijoada and its significance.
#
#
# Tell me about feijoada and its significance.
# [CLS]
#
# Tell me about feijoada and its significance.
# [CLS]
#
# Tell me about feijoada and its significance.
# [CLS]
#
# Tell me about feijoada and its significance.
# [CLS]
#
# Tell me about feijoada and its significance.
# [CLS]
#
# Tell me about feijoada and its significance.
# [CLS]
#
# Tell me about feijoada and its significance.
# [CLS]
#
# Tell me about feijoada and its significance.
# [CLS]
#
# 10
# How is feijoada similar or different from cassoulet?
# many varieties of portuguese - style chourico and linguica are used in many different
#
# 10
# Tell about Bigos stew.
# [CLS]
#
# Tell about Bigos stew.
# [CLS]
#
# Tell about Bigos stew.
# [CLS]
#
# Tell about Bigos stew.
# [CLS]
#
# Tell about Bigos stew.
# [CLS]
#
# Tell about Bigos stew.
# [CLS]
#
# Tell about Bigos stew.
# [CLS]
#
# Tell about Bigos stew.
# [CLS]
#
# Tell about Bigos stew.
# [CLS]
#
# Tell about Bigos stew.
# in from a polish country house kitchen
#
# 10
# Why is Bigos stew important?
# [CLS]
#
# Why is Bigos stew important?
# [CLS]
#
# Why is Bigos stew important?
# [CLS]
#
# Why is Bigos stew important?
# [CLS] why is bigos stew important? [SEP] polish food is delicious! if you are wondering what the people of poland typically eat, here is a list of traditional polish food. if it sounds good to you, be sure to check out our polish recipe section and make your own polish dishes! bigos. bigos is a traditional stew ( hunter's stew ) and is considered to be the national dish of poland
#
# 10
# What is the history of Irish stew?
# [CLS]
#
# What is the history of Irish stew?
# [CLS]
#
# What is the history of Irish stew?
# [CLS]
#
# What is the history of Irish stew?
# [CLS]
#
# What is the history of Irish stew?
# [CLS]
#
# What is the history of Irish stew?
# [CLS]
#
# What is the history of Irish stew?
# [CLS]
#
# What is the history of Irish stew?
# [CLS]
#
# What is the history of Irish stew?
# [CLS]
#
# What is the history of Irish stew?
# [CLS]
#
# 10
# What is the keto diet?
# low - carb, high fat
#
# 10
# Why was keto diet originally developed?
# to treat patients with epilepsy
#
# 10
# What is ketosis?
# [CLS]
#
# What is ketosis?
# [CLS]
#
# What is ketosis?
# [CLS]
#
# What is ketosis?
# [CLS]
#
# What is ketosis?
# [CLS]
#
# What is ketosis?
# [CLS]
#
# What is ketosis?
# [CLS]
#
# What is ketosis?
# [CLS]
#
# What is ketosis?
# [CLS]
#
# What is ketosis?
# [CLS]
#
# 10
# What is paleo diet?
# [CLS]
#
# What is paleo diet?
# [CLS]
#
# What is paleo diet?
# [CLS]
#
# What is paleo diet?
#
#
# What is paleo diet?
# [CLS]
#
# What is paleo diet?
# [CLS]
#
# What is paleo diet?
# [CLS]
#
# What is paleo diet?
# [CLS]
#
# What is paleo diet?
# [CLS]
#
# What is paleo diet?
# [CLS]
#
# 10
# What do paleo diet and keto diet have in common?
# [CLS]
#
# What do paleo diet and keto diet have in common?
# [CLS]
#
# What do paleo diet and keto diet have in common?
# [CLS]
#
# What do paleo diet and keto diet have in common?
# [CLS]
#
# What do paleo diet and keto diet have in common?
# [CLS]
#
# What do paleo diet and keto diet have in common?
# [CLS]
#
# What do paleo diet and keto diet have in common?
# [CLS]
#
# What do paleo diet and keto diet have in common?
# [CLS]
#
# What do paleo diet and keto diet have in common?
# [CLS]
#
# What do paleo diet and keto diet have in common?
# [CLS]
#
# 10
# How are paleo diet and keto diet different?
# [CLS]
#
# How are paleo diet and keto diet different?
# [CLS]
#
# How are paleo diet and keto diet different?
# paleo doesnat avoid potatoes, sweet potatoes, carrots, and other tubers and root vegetables
#
# 10
# What is intermittent fasting?
# [CLS]
#
# What is intermittent fasting?
# [CLS]
#
# What is intermittent fasting?
# [CLS]
#
# What is intermittent fasting?
# [CLS]
#
# What is intermittent fasting?
# [CLS]
#
# What is intermittent fasting?
# [CLS]
#
# What is intermittent fasting?
# [CLS]
#
# What is intermittent fasting?
# [CLS]
#
# What is intermittent fasting?
# [CLS]
#
# What is intermittent fasting?
# juice fasts and cleanses to help improve my health
#
# 10
# How is intermittent fasting related to keto?
# [CLS]
#
# How is intermittent fasting related to keto?
# [CLS]
#
# How is intermittent fasting related to keto?
# [CLS]
#
# How is intermittent fasting related to keto?
# [CLS]
#
# How is intermittent fasting related to keto?
# without deprivation
#
# 10
# What is the 16_8 method in intermittent fasting?
# [CLS]
#
# What is the 16_8 method in intermittent fasting?
# [CLS]
#
# What is the 16_8 method in intermittent fasting?
# [CLS]
#
# What is the 16_8 method in intermittent fasting?
# [CLS]
#
# What is the 16_8 method in intermittent fasting?
# [CLS]
#
# What is the 16_8 method in intermittent fasting?
# [CLS]
#
# What is the 16_8 method in intermittent fasting?
# [CLS]
#
# What is the 16_8 method in intermittent fasting?
# [CLS]
#
# What is the 16_8 method in intermittent fasting?
# [CLS]
#
# What is the 16_8 method in intermittent fasting?
# [CLS]
#
# 10
# What is the best method for weight loss?
# [CLS]
#
# What is the best method for weight loss?
# [CLS]
#
# What is the best method for weight loss?
# [CLS]
#
# What is the best method for weight loss?
# [CLS]
#
# What is the best method for weight loss?
# [CLS]
#
# What is the best method for weight loss?
# [CLS]
#
# What is the best method for weight loss?
# [CLS]
#
# What is the best method for weight loss?
# [CLS]
#
# What is the best method for weight loss?
# [CLS]
#
# What is the best method for weight loss?
# [CLS]
#
# 10
# What is taught in sociology?
# [CLS]
#
# What is taught in sociology?
# [CLS]
#
# What is taught in sociology?
# [CLS]
#
# What is taught in sociology?
# [CLS]
#
# What is taught in sociology?
# [CLS]
#
# What is taught in sociology?
# [CLS]
#
# What is taught in sociology?
# [CLS]
#
# What is taught in sociology?
# [CLS]
#
# What is taught in sociology?
# [CLS]
#
# What is taught in sociology?
# [CLS]
#
# 10
# What is the main contribution of Auguste Comte to sociology?
# [CLS]
#
# What is the main contribution of Auguste Comte to sociology?
# [CLS]
#
# What is the main contribution of Auguste Comte to sociology?
# [CLS]
#
# What is the main contribution of Auguste Comte to sociology?
# [CLS]
#
# What is the main contribution of Auguste Comte to sociology?
# [CLS]
#
# What is the main contribution of Auguste Comte to sociology?
# [CLS]
#
# What is the main contribution of Auguste Comte to sociology?
# [CLS]
#
# What is the main contribution of Auguste Comte to sociology?
# [CLS]
#
# What is the main contribution of Auguste Comte to sociology?
# [CLS] what is the main contribution of auguste comte to sociology? [SEP] religiously, wright was an agnostic, arguing that we should suspend judgment on the existence of god because there is no firm evidence either way. william james's famous will - to - believe argument was partly aimed at wright's brand of agnosticism. in ethics, he embraced utilitarianism, agreeing with john stuart mill that pleasures differ in quality as well as quantity. he was a staunch critic of herbert spencer's attempt to extend darwinism into a law of cosmic and social progress. like mill and auguste comte, wright embraced a positivistic approach to science that rejects the possibility ( or even meaningfulness ) of metaphysics
#
# 10
# What is the role of positivism in sociology?
# [CLS]
#
# What is the role of positivism in sociology?
# [CLS]
#
# What is the role of positivism in sociology?
# [CLS]
#
# What is the role of positivism in sociology?
# [CLS]
#
# What is the role of positivism in sociology?
# valuable for its potential to solve social problems and to reorganize society
#
# 10
# What is Herbert Spencer known for in sociology?
# developing and applying evolutionary theory to philosophy, psychology and the study of society - - what he called his synthetic philosophy
#
# 10
# How is Herbert Spencer's work related to Comte?
# [CLS]
#
# How is Herbert Spencer's work related to Comte?
# [CLS]
#
# How is Herbert Spencer's work related to Comte?
# [CLS]
#
# How is Herbert Spencer's work related to Comte?
# [CLS]
#
# How is Herbert Spencer's work related to Comte?
# [CLS]
#
# How is Herbert Spencer's work related to Comte?
# [CLS]
#
# How is Herbert Spencer's work related to Comte?
# [CLS]
#
# How is Herbert Spencer's work related to Comte?
# [CLS]
#
# How is Herbert Spencer's work related to Comte?
# [CLS]
#
# How is Herbert Spencer's work related to Comte?
# [CLS]
#
# 10
# What is the functionalist theory in sociology?
# [CLS]
#
# What is the functionalist theory in sociology?
# [CLS]
#
# What is the functionalist theory in sociology?
# [CLS]
#
# What is the functionalist theory in sociology?
# a system that is largely cultural, learned through social interaction
#
# 10
# What is the main criticism of functionalist theory in sociology?
# [CLS]
#
# What is the main criticism of functionalist theory in sociology?
#
#
# What is the main criticism of functionalist theory in sociology?
# [CLS]
#
# What is the main criticism of functionalist theory in sociology?
# [CLS]
#
# What is the main criticism of functionalist theory in sociology?
# [CLS]
#
# What is the main criticism of functionalist theory in sociology?
# [CLS]
#
# What is the main criticism of functionalist theory in sociology?
# [CLS]
#
# What is the main criticism of functionalist theory in sociology?
# [CLS]
#
# What is the main criticism of functionalist theory in sociology?
# [CLS]
#
# What is the main criticism of functionalist theory in sociology?
# funerals often serve as political events among communities
#
# 10
# How does functionalist theory compare to conflict theory?
# [CLS]
#
# How does functionalist theory compare to conflict theory?
# macro approaches
#
# 10
# What are modern examples of conflict theory?
# [CLS]
#
# What are modern examples of conflict theory?
# [CLS]
#
# What are modern examples of conflict theory?
# [CLS]
#
# What are modern examples of conflict theory?
# [CLS]
#
# What are modern examples of conflict theory?
# [CLS]
#
# What are modern examples of conflict theory?
# [CLS]
#
# What are modern examples of conflict theory?
# [CLS]
#
# What are modern examples of conflict theory?
# [CLS]
#
# What are modern examples of conflict theory?
# traditional collectivism and modern individualism
#
# 10
# What were the purposes of the Lewis and Clark expedition?
# [CLS]
#
# What were the purposes of the Lewis and Clark expedition?
# to explore the land which the united states had purchased from france through the louisiana purchase in 1803
#
# 10
# What were important plants and animals Lewis and Clark discovered?
# [CLS]
#
# What were important plants and animals Lewis and Clark discovered?
# many species
#
# 10
# What were the diplomatic objectives of the Lewis and Clark expedition?
# [CLS] what were the diplomatic objectives of the lewis and clark expedition? [SEP] by 1811 the first corps of discovery under captain lewis and lieutenant clark has been considered lost for 5 years. any country that attempted to map the pacific coast by land or sea routes has completely failed. the united states of america has yet to press its claims for the louisiana purchase. president james madison fears a british invasion, with the support of a unified indian nation under tecumseh, that would claim the northwest territories and cause a dissolution of the union. under these dire threats, a second corps of discovery is formed as a military expedition to reach the west coast. its primary goals are to learn what happened to lewis and clark and the first corps members, and find the mythical " all - water route " across north america
#
# 10
# What were the Native American tribes that Lewis and Clark encountered?
# [CLS]
#
# What were the Native American tribes that Lewis and Clark encountered?
# omaha
#
# 10
# How did Sacagawea help Lewis and Clark?
# [CLS]
#
# How did Sacagawea help Lewis and Clark?
# [CLS]
#
# How did Sacagawea help Lewis and Clark?
# carrying her infant son on her back
#
# 10
# Did Lewis and Clark find the Northwest Passage?
# never saw the cavern
#
# 10
# What was the purpose of Fort Mandan in the Lewis and Clark expedition?
# made preparations for heading westward to the pacific ocean
#
# 10
# How did Lewis and Clark spend the next winter?
# [CLS]
#
# How did Lewis and Clark spend the next winter?
# [CLS]
#
# How did Lewis and Clark spend the next winter?
# [CLS]
#
# How did Lewis and Clark spend the next winter?
# [CLS]
#
# How did Lewis and Clark spend the next winter?
# [CLS]
#
# How did Lewis and Clark spend the next winter?
# in the nearby region
#
# 10
# What happened to Fort Clatsop?
# [CLS]
#
# What happened to Fort Clatsop?
# [CLS]
#
# What happened to Fort Clatsop?
# [CLS]
#
# What happened to Fort Clatsop?
# [CLS]
#
# What happened to Fort Clatsop?
# [CLS]
#
# What happened to Fort Clatsop?
# [CLS]
#
# What happened to Fort Clatsop?
# [CLS]
#
# What happened to Fort Clatsop?
# [CLS]
#
# What happened to Fort Clatsop?
# [CLS]
#
# What happened to Fort Clatsop?
# [CLS]
#
# 10
# What was the impact of the Lewis and Clark expedition?
# [CLS]
#
# What was the impact of the Lewis and Clark expedition?
# [CLS]
#
# What was the impact of the Lewis and Clark expedition?
# much used prehistoric pathway

# %%
print(question_ids)
# Out:
# ['31_1', '31_2', '31_3', '31_4', '31_5', '31_6', '31_7', '31_8', '31_9', '32_1', '32_2', '32_3', '32_4', '32_5', '32_6', '32_7', '32_8', '32_9', '32_10', '32_11', '33_1', '33_2', '33_3', '33_4', '33_5', '33_6', '33_7', '33_8', '33_9', '33_10', '34_1', '34_2', '34_3', '34_4', '34_5', '34_6', '34_7', '34_8', '34_9', '35_1', '35_2', '35_3', '35_4', '35_5', '35_6', '35_7', '35_8', '35_9', '36_1', '36_2', '36_3', '36_4', '36_5', '36_6', '36_7', '36_8', '36_9', '36_10', '36_11', '37_1', '37_2', '37_3', '37_4', '37_5', '37_6', '37_7', '37_8', '37_9', '37_10', '37_11', '37_12', '38_1', '38_2', '38_3', '38_4', '38_5', '38_6', '38_7', '38_8', '39_1', '39_2', '39_3', '39_4', '39_5', '39_6', '39_7', '39_8', '39_9', '40_1', '40_2', '40_3', '40_4', '40_5', '40_6', '40_7', '40_8', '40_9', '40_10', '41_1', '41_2', '41_3', '41_4', '41_5', '41_6', '41_7', '41_8', '41_9', '42_1', '42_2', '42_3', '42_4', '42_5', '42_6', '42_7', '42_8', '43_1', '43_2', '43_3', '43_4', '43_5', '43_6', '43_7', '43_8', '44_1', '44_2', '44_3', '44_4', '44_5', '44_6', '44_7', '44_8', '45_1', '45_2', '45_3', '45_4', '45_5', '45_6', '45_7', '45_8', '46_1', '46_2', '46_3', '46_4', '46_5', '46_6', '46_7', '46_8', '46_9', '46_10', '47_1', '47_2', '47_3', '47_4', '47_5', '47_6', '47_7', '48_1', '48_2', '48_3', '48_4', '48_5', '48_6', '48_7', '48_8', '48_9', '49_1', '49_2', '49_3', '49_4', '49_5', '49_6', '49_7', '49_8', '49_9', '49_10', '50_1', '50_2', '50_3', '50_4', '50_5', '50_6', '50_7', '50_8', '50_9', '50_10', '51_1', '51_2', '51_3', '51_4', '51_5', '51_6', '51_7', '51_8', '51_9', '51_10', '52_1', '52_2', '52_3', '52_4', '52_5', '52_6', '52_7', '52_8', '52_9', '52_10', '53_1', '53_2', '53_3', '53_4', '53_5', '53_6', '53_7', '53_8', '53_9', '54_1', '54_2', '54_3', '54_4', '54_5', '54_6', '54_7', '54_8', '54_9', '55_1', '55_2', '55_3', '55_4', '55_5', '55_6', '55_7', '55_8', '55_9', '55_10', '56_1', '56_2', '56_3', '56_4', '56_5', '56_6', '56_7', '56_8', '57_1', '57_2', '57_3', '57_4', '57_5', '57_6', '57_7', '57_8', '57_9', '57_10', '58_1', '58_2', '58_3', '58_4', '58_5', '58_6', '58_7', '58_8', '59_1', '59_2', '59_3', '59_4', '59_5', '59_6', '59_7', '59_8', '60_1', '60_2', '60_3', '60_4', '60_5', '60_6', '60_7', '61_1', '61_2', '61_3', '61_4', '61_5', '61_6', '61_7', '61_8', '61_9', '62_1', '62_2', '62_3', '62_4', '62_5', '62_6', '62_7', '62_8', '62_9', '62_10', '62_11', '63_1', '63_2', '63_3', '63_4', '63_5', '63_6', '63_7', '63_8', '63_9', '63_10', '64_1', '64_2', '64_3', '64_4', '64_5', '64_6', '64_7', '64_8', '64_9', '64_10', '64_11', '65_1', '65_2', '65_3', '65_4', '65_5', '65_6', '65_7', '65_8', '65_9', '65_10', '66_1', '66_2', '66_3', '66_4', '66_5', '66_6', '66_7', '66_8', '66_9', '67_1', '67_2', '67_3', '67_4', '67_5', '67_6', '67_7', '67_8', '67_9', '67_10', '67_11', '68_1', '68_2', '68_3', '68_4', '68_5', '68_6', '68_7', '68_8', '68_9', '68_10', '68_11', '69_1', '69_2', '69_3', '69_4', '69_5', '69_6', '69_7', '69_8', '69_9', '69_10', '70_1', '70_2', '70_3', '70_4', '70_5', '70_6', '70_7', '70_8', '70_9', '70_10', '71_1', '71_2', '71_3', '71_4', '71_5', '71_6', '71_7', '71_8', '71_9', '71_10', '71_11', '71_12', '72_1', '72_2', '72_3', '72_4', '72_5', '72_6', '72_7', '72_8', '72_9', '72_10', '73_1', '73_2', '73_3', '73_4', '73_5', '73_6', '73_7', '73_8', '73_9', '73_10', '74_1', '74_2', '74_3', '74_4', '74_5', '74_6', '74_7', '74_8', '74_9', '74_10', '74_11', '74_12', '75_1', '75_2', '75_3', '75_4', '75_5', '75_6', '75_7', '75_8', '75_9', '75_10', '76_1', '76_2', '76_3', '76_4', '76_5', '76_6', '76_7', '76_8', '76_9', '76_10', '77_1', '77_2', '77_3', '77_4', '77_5', '77_6', '77_7', '77_8', '77_9', '77_10', '78_1', '78_2', '78_3', '78_4', '78_5', '78_6', '78_7', '78_8', '78_9', '78_10', '79_1', '79_2', '79_3', '79_4', '79_5', '79_6', '79_7', '79_8', '79_9', '80_1', '80_2', '80_3', '80_4', '80_5', '80_6', '80_7', '80_8', '80_9', '80_10']

# %%
print(len(accepted_answers))
# Out:
# 479

# %%
with open('/content/accepted_answers.txt', 'w') as f:
    for a in accepted_answers:
        f.write(a + '\n')

# %%
with open('/content/accepted_answers_filtered.txt') as f:
    accepted_answers_filtered = f.readlines()

# %%
# Generate QA List
QA_answer_list = []
for t in accepted_answers_filtered :
    temp = t.strip()
    temp_split = temp.split(" ")
    if(len(temp_split) > 10):
        temp_split = temp_split[:10]
    temp_join = " ".join(temp_split)
    QA_answer_list.append(temp_join)

# %%
print(len(QA_answer_list))
print(QA_answer_list)
# Out:
# 479
# ['any cancer that forms in the throat', '', '', '', '', '', 'severe throat pain', 'a subset', 'dysphagia', '', '', '', 'blue whale', 'carcharodon megalodon', '', '', 'they are agile hunters ; built for the speed and', '', 'large marine fish', 'galeocerdo', '', '', 'it was released in 1984', '', '', "michael ende's novel the neverending story ( 1979", 'synthpop', 'bastian bux', '', 'died later that year.', '', 'placenames and personal names', '', 'europoids of the afanasevo culture', 'the myth of the ages follows. in the hesiodic scheme', 'wanda and horowitz separated in 1948 while the pianist was', 'environmental causes', 'sumerian, akkadian, babylonian and assyrian', 'the bronze age', '', 'french toile', '', '', '', 'late 19th century', '', 'in her review of the concert at the plymouth pavilions,', '', '', 'the people in each state vote for the president', 'us electoral college', 'according to a legal expert, one example of why the', 'changed the method that determines how the us vice president', '', '19 – 1796 election : samuel miles, an elector from', '', '', 'without congressional authorization', 'without congressional authorization', '', 'the wave is not the only movie to convert a', '', 'unethical', 'stanford prison experiment', '37 of 40 people were prepared to administer the highest', '', 'the extremity of this field experiment is not prototypical of', '', 'the experiment was a documentary series broadcast on bbc television', 'in 2001, haslam collaborated with steve reicher ( university of', '', 'a bacterial illness', 'if you are bitten by an infected tick', 'lyme disease and other diseases carried by ticks. ticks can', 'lyme disease is a bacterial disease that sometimes has long', '', 'the only reliable company to test for lyme', '', '', '', '', 'adults need it to keep their bones strong', 'tofu is a great natural source of calcium. chard is', 'any meat will do, though, provided it has not gone', 'beef, poultry, fish, and eggs', 'helped to increase her energy', 'veganism appears to provide health benefits, including a reduced risk', 'pales', '', '', '', '', 'this music was integrated into popular music achieving mainstream success', '', '', 'occasional indifference', 'as it came into contact with other cultures', 'thousands of years, with variations of it found in most', 'it will not change anything', 'higher than the age of majority', 'withdrawal effects and dependence are also almost identical. alcohol at', '', 'can lead to serious mental health problems', 'brain damage', '', 'low', 'there are always', '', '', '', '', '', '', '', '', '', '1837', 'closely linked', '', '', '', '', 'the del rio', '', 'the affected individuals frequently wake up in the morning with', 'zegerid', 'severe side effects', '', 'apple cider vinegar', 'baking soda does milk', 'while acid reflux refers to a condition where stomach acid', '', '', '', 'small dogs living longer', '', '', '', '', 'may not be correct in what they are teaching.', 'the complexity of a language often makes it challenging for', 'polish', '', 'which language to learn depends on where you plan to', 'high / low german, dutch and english', '', 'ren is largely used', 'krieg', '', 'it is filled with so many trees of all kinds', '', '', 'going east on interstate highway i - 90, tanner is', '', '', '', 'a list of pointers is defined to the base class', 'what is a virtual watercooler? a. a virtual place to', "virtual columns don't consume space on the disk", '', 'discrete tpms ( dtpm ), integrated tpms, firmware tpms (', 'in the software as a service ( saas ) model,', 'the operating system level architecture has low overhead that helps', 'you can observe what people actually do or say, rather', '', '', '', '', '', '', 'two of the biggest players in the space', '', 'paid - for streaming of popular box - sets', 'clearly impacted the way in which we access television, allowing', '', '', 'astronomical satellites, communication satellites, earth observation satellites, navigation sate ...

# %%
import json
jsonFile = open('/content/evaluation_topics_v1.0.json', 'r')
values = json.load(jsonFile)
sentences = []
for v in values:
    turns = v['turn']
    cur = []
    for t in turns:
        s = t['raw_utterance']
        cur.append(s)
    sentences.append(cur)
jsonFile.close()
print(sentences)
# Out:
# [['What is throat cancer?', 'Is it treatable?', 'Tell me about lung cancer.', 'What are its symptoms? ', 'Can it spread to the throat?', 'What causes throat cancer?', 'What is the first sign of it?', 'Is it the same as esophageal cancer?', "What's the difference in their symptoms?"], ['What are the different types of sharks?', 'Are sharks endangered?  If so, which species?', 'Tell me more about tiger sharks.', 'What is the largest ever to have lived on Earth?', "What's the biggest ever caught?", 'What about for great whites?', 'Tell me about makos.', 'What are their adaptations?', 'Where do they live?', 'What do they eat?', 'How do they compare with tigers for being dangerous?'], ['Tell me about the Neverending Story film.', 'What is it about?', 'How was it received?', 'Did it win any awards?', 'Was it a book first?', 'Who was the author and when what it published?', 'What are the main themes?', 'Who are the main characters?', 'What are the differences between the book and movies?', 'Did the horse Artax really die?'], ['Tell me about the Bronze Age collapse.', 'What is the evidence for it?', 'What are some of the possible causes?', 'Who were the Sea Peoples?', 'What was their role in it?', 'What other factors led to a breakdown of trade?', 'What about environmental factors?', 'What empires survived?', 'What came after it?'], ['Tell me about the history of toilets.', 'Where does the term come from?', 'Where and when was the first invented?', 'Why do the Brits call it a loo?', 'What came before them?', 'When did indoor versions become common?', 'How many types are there?', 'Why are they so important for society?', 'What is their role in film?'], ['What is the US Electoral College?', 'How does it work?', 'Tell me about its creation.', 'Why was the system chosen?', 'How has it changed over time?', "What if the electors don't vote for the pledged candidate?", 'How has this changed election outcomes?', 'Who are the Hamilton Electors and what were they trying to do?', 'How would the College be abolished?', 'How does the National Popular Vote Interstate Compact work?', 'Is it legal?'], ['What was the Stanford Experiment?', 'What did it show?', 'Tell me about the author of the experiment.', 'Was it ethical?', 'What are other similar experiments?', 'What happened in the Milgram experiment?', 'Why was it important?', 'What were the similarities and differences between the studies?', 'What about the BBC experiment?', 'What are the key findings?', 'How did the results differ?', 'Why was it ended?'], ['What is Lyme disease?', 'How do you get Lyme Disease?', 'How does it make you feel?', 'What happens if it goes untreated?', 'Can it kill you?', 'How reliable is the test?', 'Can it be cured?', 'What is Chronic Lyme?'], ['What does it mean to be a vegan?', 'What is the environmental argument for it?', 'Do you need milk for strong bones?', 'What are other good sources of calcium?', "If you don't eat any meat, at all, is it bad for you?", 'What are good sources of vitamin B12?', 'Does it help you lose weight?', 'What about its health effects versus being vegetarian?', 'How does the environmental impact compare between them?'], ['What are the origins of popular music? ', 'What are its characteristics?', 'What technological developments enabled it?', 'When and why did people start taking pop seriously? ', 'How has it been integrated into music education? ', 'Describe some of the influential pop bands. ', 'What makes a song pop punk?', 'What is the difference between it and emo?', 'How did Britpop change music?', 'What are its roots and what influenced it?'], ['Why is the drinking age in the US 21 and not 18?', 'What were the pros and cons?', 'Tell me about the negative health effects of drinking.', 'How does binge drinking affect development?', 'Can it damage mental health?', 'What are the short and long-term effects of usage on brain chemicals?', 'Are alcoholics generally depressed?', 'What are the effects on vitamins and minerals?', 'Are there a ...

# %%
QA_updated_questions = []
index = 0

for question_set in sentences:
  history = ""
  cur_set = []
  for question in question_set :
    rel_list, rel_phrase = getRelevantWords(None, history, question)
    history += question + " " + QA_answer_list[index] + " "
    index += 1
    # print(history)
    print(question + rel_phrase)
    cur_set.append(question + rel_phrase)
  QA_updated_questions.append(cur_set)

  print("------------------------------------")
# Out:
# What is throat cancer?
# Is it treatable?
# Tell me about lung cancer.
# What are its symptoms?
# Can it spread to the throat?
# What causes throat cancer?
# What is the first sign of it?
# Is it the same as esophageal cancer?
# What's the difference in their symptoms?
# ------------------------------------
# What are the different types of sharks?
# Are sharks endangered?  If so, which species? sharks?
# Tell me more about tiger sharks.
# What is the largest ever to have lived on Earth?
# What's the biggest ever caught?
# What about for great whites?
# Tell me about makos.
# What are their adaptations?
# Where do they live?
# What do they eat?
# How do they compare with tigers for being dangerous?
# ------------------------------------
# Tell me about the Neverending Story film.
# What is it about?
# How was it received?
# Did it win any awards?
# Was it a book first?
# Who was the author and when what it published?
# What are the main themes?
# Who are the main characters?
# What are the differences between the book and movies?
# Did the horse Artax really die?
# ------------------------------------
# Tell me about the Bronze Age collapse.
# What is the evidence for it? collapse.
# What are some of the possible causes?
# Who were the Sea Peoples?
# What was their role in it?
# What other factors led to a breakdown of trade?
# What about environmental factors?
# What empires survived?
# What came after it?
# ------------------------------------
# Tell me about the history of toilets.
# Where does the term come from?
# Where and when was the first invented?
# Why do the Brits call it a loo?
# What came before them?
# When did indoor versions become common?
# How many types are there?
# Why are they so important for society?
# What is their role in film?
# ------------------------------------
# What is the US Electoral College?
# How does it work? Electoral
# Tell me about its creation.
# Why was the system chosen?
# How has it changed over time? electoral
# What if the electors don't vote for the pledged candidate? electoral
# How has this changed election outcomes? electoral
# Who are the Hamilton Electors and what were they trying to do?
# How would the College be abolished?
# How does the National Popular Vote Interstate Compact work?
# Is it legal?
# ------------------------------------
# What was the Stanford Experiment?
# What did it show?
# Tell me about the author of the experiment.
# Was it ethical?
# What are other similar experiments?
# What happened in the Milgram experiment?
# Why was it important?
# What were the similarities and differences between the studies?
# What about the BBC experiment?
# What are the key findings?
# How did the results differ?
# Why was it ended?
# ------------------------------------
# What is Lyme disease?
# How do you get Lyme Disease?
# How does it make you feel?
# What happens if it goes untreated?
# Can it kill you?
# How reliable is the test?
# Can it be cured?
# What is Chronic Lyme?
# ------------------------------------
# What does it mean to be a vegan?
# What is the environmental argument for it?
# Do you need milk for strong bones?
# What are other good sources of calcium?
# If you don't eat any meat, at all, is it bad for you?
# What are good sources of vitamin B12?
# Does it help you lose weight?
# What about its health effects versus being vegetarian?
# How does the environmental impact compare between them?
# ------------------------------------
# What are the origins of popular music?
# What are its characteristics?
# What technological developments enabled it?
# When and why did people start taking pop seriously?
# How has it been integrated into music education?
# Describe some of the influential pop bands.
# What makes a song pop punk?
# What is the difference between it and emo?
# How did Britpop change music?
# What are its roots and what influenced it?
# ------------------------------------
# Why is the drinking age in the US 21 and not 18?
# What were the pros and cons?
# Tell me about the negative health effects of drinking.
# How does binge drinking affect development?
# Can it damage mental health?
# What are the short and long-term effects of usage on brain chemicals?
# Are alcoholics generally depressed?
# What are the effects on vitamins and minerals? depressed?
# Are there any benefits?
# ------------------------------------
# What is Chattanooga famous for?
# What is there to do in downtown Chattanooga?
# Are there tourism activities related to trucks or trains?
# Are there any related to Bessie Smith?
# Can I visit some nearby distilleries?
# What is Rock City, and why is it famous?
# Are special events held there?
# What kind of food is Chattanooga known for?
# ------------------------------------
# What are some interesting things around Ann Arbor?
# Tell me about when the city was founded.
# How does it relate to the establishment of the University?
# Does the Museum of Art have any special collections?
# What is the South Pond Nature Area?
# Are there any film festivals?
# How about for jazz?
# What are popular bars or clubs where I can listen to it?
# ------------------------------------
# What causes acidic reflux in the morning?
# Does it have long term side effects?
# What is the best OTC for it?
# What are the side effects of long term PPI use?
# Tell me about natural treatments.
# What foods cause it?
# What ones reduce it?
# How does exercise affect it?
# ------------------------------------
# What dog breed is the best for playing?
# What kind should I get if I’m allergic?
# How about big and active dogs?
# Do big dogs live longer than small dogs?
# Will I need to put a lot of time into training?
# Tell me about some breeds that are independent and can be left home all day.
# How much does a Irish Wolfhound weigh?
# How much do they cost?
# ------------------------------------
# Why is learning a second language difficult?
# At what age is it harder and why?
# If I already know English, which language would be the easiest to learn?
# How can I begin learning Norwegian?
# Is it easier to learn than Spanish?
# What other languages are closest to it?
# Describe some of its similarities with Danish.
# How did all these languages evolve?
# How is it related to Old Norse?
# Are there advantages of knowing multiple languages?
# ------------------------------------
# Why is Boise called the city of trees?
# How did it get its name?
# What is there to do in the summer?
# What are popular hiking trails?
# Tell me about the Oregon Trail Reserve.
# Tell me about the history of the Boise Greenbelt.
# What is the controversy around it?
# ------------------------------------
# What is the main function of a virtual machine?
# What are its advantages?
# Describe some of its disadvantages.
# How do they work?
# What are the main types of VMs?
# What is their role in cloud computing?
# How is a container different?
# What is the advantage of Docker?
# How is it related Kurbenetes?
# ------------------------------------
# How was Netflix started?
# How did it originally work? How
# What is its relationship with Blockbuster?
# When did Netflix shift from DVDs to a streaming service?
# What are its other competitors?
# How does it compare to Amazon Prime Video?
# Describe it’s subscriber growth over time.
# How has it changed the way TV is watched?
# How has it impacted society?
# How about dating and relationships?
# ------------------------------------
# What was the first artificial satellite?
# What are the types of orbits?
# What are the important classes of satellite?
# How do navigation systems work?
# What is the Galileo system and why is it important?
# Why did it create tension with the US?
# What are Cubesats?
# What are their advantages?
# What are they used for?
# What is their future?
# ------------------------------------
# How do I save for a child’s college education in the US?
# What is a 529 plan?
# How does it work?
# What are the main advantages?
# What about disadvantages?
# How long have they been around?
# What are the types of plans?
# What can the funds be used for?
# What happens if it’s not used?
# How does a ESA compare?
# ------------------------------------
# Describe the Afra tanker scale.
# Why was it developed?
# What are supertankers?
# Describe their invention.
# What are the important factors led to their development?
# What was the role of the Six-Day War?
# How many barrels can a VLCC ship carry?
# What is the largest in the world?
# What new problem did increased scale create? scale.
# Describe crude oil washing. scale
# ------------------------------------
# Is Red Bull bad for you?
# Can it kill you?
# How much can you drink in a day?
# What is taurine?
# What are its health effects?
# In general, what are the effects of consuming energy drinks?
# Why are they harmful when mixed with alcohol?
# What is the argument for their age restriction to kids?
# Where are they banned to minors?
# ------------------------------------
# What is worth seeing in Washington D.C.?
# Which Smithsonian museums are the most popular?
# Why is the National Air and Space Museum important?
# Is the Spy Museum free?
# What is there to do in DC after the museums close?
# What is the best time to visit the reflecting pools?
# Are there any famous foods?
# What is a DC half smoke?
# Tell me about its history.
# ------------------------------------
# Describe the oceanic crust.
# What are the main layers?
# How does it differ from the continental crust?
# Which is younger and why?
# Where is the youngest oceanic found?
# What about the oldest?
# What is seafloor spreading?
# What is its significance?
# How is ocean crust formed?
# Is it being recycled?
# ------------------------------------
# What is Darwin’s theory in a nutshell?
# How was it developed?
# How do sexual and asexual reproduction affect it?
# How can fossils be used to understand it?
# What is modern evidence for it?
# What is the impact on modern biology?
# Compare and contrast microevolution and macroevolution.
# What is the relationship to speciation?
# ------------------------------------
# How can you tell if someone is suffering from depression?
# What are common types?
# What causes it?
# What is the role of brain chemicals?
# Does a lack of sunlight cause it?
# How can you treat SAD?
# What is the role of melatonin?
# How are anxiety and depression related?
# What treatments exist for depression?
# What is CBT and how does it work? depression?
# ------------------------------------
# What is a real-time database?
# How does it differ from traditional ones?
# What are the advantages of real-time processing?
# What are examples of important ones?
# What are important applications?
# What are important cloud options?
# Tell me about the Firebase DB.
# How is it used in mobile apps?
# ------------------------------------
# Which weekend sports have the most injuries?
# What are the most common types of injuries?
# What is the ACL? injuries?
# What is an injury for it? injuries?
# Tell me about the RICE method.
# Is there disagreement about it?
# What is arnica used for?
# What are some ways to avoid injury?
# ------------------------------------
# Tell me about the benefits of yoga.
# Does it help in reducing stress?
# What are some of the main types?
# What type is best for losing weight?
# What are common poses in Bikram yoga?
# Why is mindful breathing important?
# Does it help relieve asthma?
# ------------------------------------
# Who are The Avengers?
# Tell me about their first appearance.
# Who is the most powerful and why?
# What is the relationship of Spider-Man to the team?
# Why is Batman not a member?
# What is an important team in the DC universe?
# Tell me about the origins of the Justice League.
# Who are the important members?
# Which team came first?
# ------------------------------------
# What is the Surrealism movement in art?
# What are its characteristics?
# Tell me about its founding.
# Tell me about the series of manifestos.
# How is it different from Dada?
# What is its importance?
# Who are the most famous artists?
# Why did Dali choose surrealism?
# What are his most iconic works?
# Is it still used today?
# What has its impact been on other fields?
# ------------------------------------
# What is blockchain?
# What problem does it solve?
# How does it work?
# What are the types of networks?
# Tell me about its invention.
# How is it related to cryptocurrencies?
# How is Bitcoin generated?
# How secure is blockchain?
# What are its other uses in business?
# What are the implications for society?
# ------------------------------------
# What are the types of pork ribs?
# What are baby backs?
# What are the differences with spareribs?
# What are ways to cook them?
# How about on the bbq?
# Describe the 321 method.
# How long do they take to smoke?
# How do you know when they are done?
# What is in a typical rub?
# What’s the best style of sauce for them?  grilled
# What’s in Kansas City style sauce?
# ------------------------------------
# What is nominal GDP?
# Why is it not a good measure?
# What is the difference with real?
# How is it related to gross national income?
# What is the meaning of GNI?
# How is inflation affected by high GDP growth?
# What is the relationship between inflation and unemployment?
# What is frictional unemployment and why is it important?
# Is it bad for the economy?
# How can the government reduce its level?
# ------------------------------------
# Tell me about lavender plants.
# What are the different types?
# What places are famous for them?
# Are they safe to eat?
# What variety is best for cooking?
# How is it used?
# What is it good with?
# What are the health benefits of its oil?
# Are there any side effects?
# ------------------------------------
# Why is blood red?
# What are red blood cells?
# How are they created?
# How is oxygen transported?
# What is anemia?
# What are the symptoms?
# Can it go away?
# What are its possible causes?
# How is it treated?
# What foods contain high levels of iron?
# What improves absorption?
# ------------------------------------
# What is cuisine is Emilia-Romagna famous for?
# Tell me about cooking schools and classes.
# What are famous foods from the region?
# Describe the traditional process for making balsamic vinegar?
# What is mortadella and where is it from?
# What’s the difference with Bologna?
# Where was Parmesan cheese created?
# What is done with the whey after production?
# What are typical pasta dishes?
# What is the history of tagliatelle al ragu bolognese?
# What are its common variations?
# ------------------------------------
# How do you sleep after jet lag?
# Does melatonin help?
# How was it discovered?
# What are good sources in food?
# Is melatonin bad for you?
# What are the side effects?
# Why does it require a prescription in the UK?
# How can I increase my levels naturally?
# Is it effective for treating insomnia?
# How about for anxiety?
# ------------------------------------
# What is solar energy?
# What are its main uses?
# Why is it important?
# What are advantages of solar energy?
# What is the cost of solar power?
# How is being used in rural Africa?
# Tell me more about solar cookers work.
# How is solar used in architecture?
# What are important projects?
# Can it be used to power cars?
# ------------------------------------
# What are mammals?
# What are their key characteristics?
# How many legs do they have?
# What is the largest one on land?
# What is the largest in the world?
# What about in the UK?
# What about the largest to ever walk the earth?
# Tell me about Blue whales.
# How much do they weigh?
# Where do they live?
# What do they eat?
# Where can we see them?
# ------------------------------------
# What do Spanish people do on Christmas day?
# What do they eat for dinner?
# How about on Christmas eve? br br
# What is the Christmas Lottery? br
# How does the drawing work?
# How are the tickets sold?
# What is Tió de Nadal?
# How did this tradition start?
# How do they celebrate Three Kings Day?
# What cakes are traditional?
# ------------------------------------
# Who is the most successful pirate of all time?
# Who is the most famous female?
# Tell me more about Ching Shih.
# What were her code of laws?
# How did she die?
# Who was Anne Bonny?
# What was she famous for?
# Who was she married to?
# How did Calico Jack die?
# What happened to Anne?
# ------------------------------------
# What are the pros and cons of electric cars?
# Tell me more about Tesla.
# Why did Elon Musk start it?
# What models are available?
# What is the best selling?
# What is unique about the Model 3?
# What are the safety features?
# Why is it building Gigafactories?
# What makes the batteries unique?
# How long can they last?
# Tell me more about autopilot.
# Does it support full self-driving?
# ------------------------------------
# Why do turkey and Turkey share the same name?
# Where are turkeys from?
# What was their importance in native cultures?
# When and how were they domesticated?
# Can they fly?
# Why did Ben Franklin want it to be the national symbol?
# How did he cook it?
# Why is it eaten on Thanksgiving?
# How did it become traditional for Christmas dinner in Britain?
# When did they become popular?
# ------------------------------------
# What are important literary elements?
# What is the difference between them and literary devices?
# What is a genre?
# What are the most important ones?
# What is a trope? theology
# What are important examples in fantasy?
# What is the definition of allegory?
# What are some important modern uses?
# What are the different types of foreshadowing?
# What is an example?
# ------------------------------------
# What's the difference between soup and stew?
# Is chilli a stew?
# How about goulash?
# What are popular ones in France?
# How is cassoulet made?
# Tell me about feijoada and its significance.
# How is it similar or different from cassoulet?
# Tell about Bigos stew.
# Why is it important?
# What is the history of Irish stew?
# ------------------------------------
# What is the keto diet?
# Why was it original developed?
# What is ketosis?
# What is paleo?
# What do they have in common?
# How are they different?
# What is intermittent fasting?
# How is it related to keto?
# What is the 16/8 method?
# What is the best for weight loss?
# ------------------------------------
# What is taught in sociology?
# What is the main contribution of Auguste Comte?
# What is the role of positivism in it?
# What is Herbert Spencer known for?
# How is his work related to Comte?
# What is the functionalist theory?
# What is its main criticism?
# How does it compare to conflict theory?
# What are modern examples of conflict theory?
# ------------------------------------
# What were the purposes of the Lewis and Clark expedition?
# What were important plants and animals they discovered?
# What were the diplomatic objectives?
# What were the Native American tribes that they encountered?
# How did Sacagawea help them?
# Did they find the Northwest Passage?
# What was the purpose of Fort Mandan?
# How did they spend the next winter?
# What happened to Fort Clatsop?
# What was the impact of the expedition?
# ------------------------------------

# %%
n = 31
i = 1
with open('/content/qa_updated.txt', 'a') as f:
    for cur in QA_updated_questions:
        i = 1
        for l in cur:
            line = '{"number" : "' + str(n) + '_' + str(i) + '", "text" : "#combine(' + l + ')"},\n'
            f.write(line)
            i = i + 1
        n = n + 1
